# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) SQL JOINS
# Week 6 | Lesson 1.1

# %% [markdown]
# ### LEARNING OBJECTIVES
# *After this lesson, you will be able to:*
# - explain what a `JOIN` operation is
# - visualize a `JOIN` operation as an operation between sets
# - distinguish different types of `JOIN`
# - perform `JOINS` in `SQL`

# %% [markdown]
# ### STUDENT PRE-WORK
# *Before this lesson, you should already be able to:*
# - connect to a local or remote relational database
# - perform SQL CRUD actions and queries
# - merge dataframes with Pandas.merge

# %% [markdown]
# ### LESSON GUIDE
# | TIMING  | TYPE  | TOPIC  |
# |:-:|---|---|
# | 5 mins | [Opening](#opening) | Opening |
# | 15 mins | [Introduction](#introduction) | Joining tables |
# | 15 mins | [Demo](#demo) | Demo: Different types of JOIN |
# | 15 mins | [Guided-practice](#guided-practice) | Guided Practice: Other Joins |
# | 15 mins | [Demo](#demo_2) | Demo: Sub-queries |
# | 25 minutes | [Ind-practice](#ind-practice) | Independent Practice: Other SQL Commands |
# | 5 mins | [Conclusion](#conclusion) | Conclusion |

# %% [markdown]
# <a name="opening"></a>
# ## Opening (5 mins)
# Last week we learned many things about databases, including:
#
# - how to connect to a local or remote db
# - how to add, remove, edit data
# - how to perform simple queries
# - how to aggregate, group and sort data
#
# > **Check:** What SQL commands did we learn last week? What do they do?
#
# We often need to use data stored in more than one table. Last week we did this using `Pandas merge`, but time has come to learn about _`JOIN`_, which is the natural way to merge data within `SQL`.

# %% [markdown]
# <a name="introduction"></a>
# ## Joining tables (15 mins)
#
# We will use the [Northwind sample database](https://northwinddatabase.codeplex.com/):
#
#     psql -h dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com -p 5432 -U dsi_student northwind
#     password: gastudents
#
# As a reminder, here are what some of the tables looks like:
#
# `customers`:
#
# |CustomerID |CompanyName |ContactName | ContactTitle |Address|City | Region | PostalCode | Country |Phone | Fax|
# |---|
# |ALFKI| Alfreds Futterkiste| Maria Anders | Sales Representative | Obere Str. 57 | Berlin|| 12209| Germany | 030-0074321| 030-0076545|
# |ANATR| Ana Trujillo Emparedados y helados | Ana Trujillo | Owner| Avda. de la Constitución 2222 | México D.F. || 05021| Mexico| (5) 555-4729 | (5) 555-3745|
# |ANTON| Antonio Moreno Taquería| Antonio Moreno | Owner| Mataderos2312 | México D.F. || 05023| Mexico| (5) 555-3932 |
# |...|...|...|...|...|...|...|...|...|...|...|

# %% [markdown]
# `orders`:
#
# |OrderID | CustomerID | EmployeeID | OrderDate| RequiredDate | ShippedDate | ShipVia | Freight | ShipName|ShipAddress |ShipCity| ShipRegion | ShipPostalCode | ShipCountry |
# |----|
# |10248 | VINET|5 | 1996-07-04 | 1996-08-01 | 1996-07-16| 3 | 32.38 | Vins et alcools Chevalier | 59 rue de l'Abbaye | Reims|| 51100| France|
# |10249 | TOMSP|6 | 1996-07-05 | 1996-08-16 | 1996-07-10| 1 | 11.61 | Toms Spezialitäten| Luisenstr. 48| Münster|| 44087| Germany|
# |10250 | HANAR|4 | 1996-07-08 | 1996-08-05 | 1996-07-12| 2 | 65.83 | Hanari Carnes | Rua do Paço, 67| Rio de Janeiro | RJ | 05454-876| Brazil|
# |...|...|...|...|...|...|...|...|...|...|...|

# %% [markdown]
# `order_details`:
#
# | OrderID |  ProductID |  UnitPrice | Quantity | Discount |
# | ----- |
# |10248|11|14|12|0|
# |10248|42|9.8|10|0|
# |10248|72|34.8|5|0|
# |10249|14|18.6|9|0|
# |10249|51|42.4|40|0|
# |10250|41|7.7|10|0|
# |...|...|...|...|...|

# %% [markdown]
# ### Joins
#
# _SQL joins_ are used when data is spread across different tables. A _join_ operation combines rows from two or more tables in a single new table. To do this, there needs to be a common field between the tables.
#
# Join operations can be thought of as operations between two sets, where records with the same key are combined and records missing in one set are either discarded or included as NULL values.
#
# > **Check:** where have you encountered a similar functionality in Pandas? How have you used it?

# %% [markdown]
# #### INNER JOIN
# The most common type of join is: SQL INNER JOIN (simple join). An SQL INNER JOIN returns all rows from multiple tables where the join condition is met.
#
# Let's consider a few columns of the `orders` table above:
#
# |OrderID|CustomerID|OrderDate|
# |---|---|---|
# |10308|2|1996-09-18|
# |10309|37|1996-09-19|
# |10310|77|1996-09-20|

# %% [markdown]
# In the `customers` table, let's focus on these columns:
#
# |CustomerID|CompanyName|ContactName|Country|
# |---|---|---|---|
# |1|Alfreds Futterkiste|Maria Anders|Germany|
# |2|Ana Trujillo Emparedados y helados|Ana Trujillo|Mexico|
# |3|Antonio Moreno Taquería|Antonio Moreno|Mexico|

# %% [markdown]
# Notice that the `CustomerID` column in the `Orders` table refers to the `CustomerID` in the `Customers` table. We can _JOIN_ the two tables in order to obtain a table like the following:
#
# |OrderID|CompanyName|OrderDate|
# |---|---|---|
# |10308|Ana Trujillo Emparedados y helados|9/18/1996|
# |10365|Antonio Moreno Taquería|11/27/1996|
# |10383|Around the Horn|12/16/1996|
# |10355|Around the Horn|11/15/1996|
# |10278|Berglunds snabbköp|8/12/1996|
#
# A selection of the information contained in the two tables is _joined_ in a single table, using the common key of `CustomerID`.

# %% [markdown]
# #### Comparison with Pandas Merge
#
# See [here](http://pandas.pydata.org/pandas-docs/stable/comparison_with_sql.html) for a comparison between pandas and SQL and [here](http://pandas.pydata.org/pandas-docs/stable/merging.html#database-style-dataframe-joining-merging) for an in depth review of Pandas merge.

# %% [markdown]
# <a name="demo"></a>
# ## Demo: Different types of JOIN (15 mins)
#
# |OrderID|CompanyName|OrderDate|
# |---|---|---|
# |10308|Ana Trujillo Emparedados y helados|9/18/1996|
# |10365|Antonio Moreno Taquería|11/27/1996|
# |10383|Around the Horn|12/16/1996|
# |10355|Around the Horn|11/15/1996|
# |10278|Berglunds snabbköp|8/12/1996|
#
# We created this result with this statement:
#
#
# ```sql
#     SELECT orders."OrderID", customers."CompanyName", orders."OrderDate"
#     FROM orders
#     INNER JOIN customers
#     ON orders."CustomerID"=customers."CustomerID";
# ```
#
# An `INNER JOIN` takes the intersection of the two datasets, excluding the rows for which `CustomerID` is null in either of the two tables.

# %% [markdown]
# psql -h dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com -p 5432 -U dsi_student northwind password: gastudents

# %%
# %load_ext sql

import psycopg2
from pandas.io import sql
login={ 'dbname': 'northwind',
      'user':'dsi_student',
      'port':5432,
      'host':'dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com',
      'password':'gastudents'}

conn=psycopg2.connect(**login)
c=conn.cursor()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# Out:
# u'Connected: dsi_student@northwind'

# %%
# %%sql
# SELECT orders."OrderID",customers."CompanyName",orders."OrderDate"
# FROM orders
# INNER JOIN customers
# ON orders."CustomerID"=customers."CustomerID"
# Out:
# 830 rows affected.
# [(10248, u'Vins et alcools Chevalier', datetime.date(1996, 7, 4)),
#  (10249, u'Toms Spezialit\xe4ten', datetime.date(1996, 7, 5)),
#  (10250, u'Hanari Carnes', datetime.date(1996, 7, 8)),
#  (10251, u'Victuailles en stock', datetime.date(1996, 7, 8)),
#  (10252, u'Supr\xeames d\xe9lices', datetime.date(1996, 7, 9)),
#  (10253, u'Hanari Carnes', datetime.date(1996, 7, 10)),
#  (10254, u'Chop-suey Chinese', datetime.date(1996, 7, 11)),
#  (10255, u'Richter Supermarkt', datetime.date(1996, 7, 12)),
#  (10256, u'Wellington Importadora', datetime.date(1996, 7, 15)),
#  (10257, u'HILARION-Abastos', datetime.date(1996, 7, 16)),
#  (10258, u'Ernst Handel', datetime.date(1996, 7, 17)),
#  (10259, u'Centro comercial Moctezuma', datetime.date(1996, 7, 18)),
#  (10260, u'Ottilies K\xe4seladen', datetime.date(1996, 7, 19)),
#  (10261, u'Que Del\xedcia', datetime.date(1996, 7, 19)),
#  (10262, u'Rattlesnake Canyon Grocery', datetime.date(1996, 7, 22)),
#  (10263, u'Ernst Handel', datetime.date(1996, 7, 23)),
#  (10264, u'Folk och f\xe4 HB', datetime.date(1996, 7, 24)),
#  (10265, u'Blondesddsl p\xe8re et fils', datetime.date(1996, 7, 25)),
#  (10266, u'Wartian Herkku', datetime.date(1996, 7, 26)),
#  (10267, u'Frankenversand', datetime.date(1996, 7, 29)),
#  (10268, u'GROSELLA-Restaurante', datetime.date(1996, 7, 30)),
#  (10269, u'White Clover Markets', datetime.date(1996, 7, 31)),
#  (10270, u'Wartian Herkku', datetime.date(1996, 8, 1)),
#  (10271, u'Split Rail Beer & Ale', datetime.date(1996, 8, 1)),
#  (10272, u'Rattlesnake Canyon Grocery', datetime.date(1996, 8, 2)),
#  (10273, u'QUICK-Stop', datetime.date(1996, 8, 5)),
#  (10274, u'Vins et alcools Chevalier', datetime.date(1996, 8, 6)),
#  (10275, u'Magazzini Alimentari Riuniti', datetime.date(1996, 8, 7)),
#  (10276, u'Tortuga Restaurante', datetime.date(1996, 8, 8)),
#  (10277, u'Morgenstern Gesundkost', datetime.date(1996, 8, 9)),
#  (10278, u'Berglunds snabbk\xf6p', datetime.date(1996, 8, 12)),
#  (10279, u'Lehmanns Marktstand', datetime.date(1996, 8, 13)),
#  (10280, u'Berglunds snabbk\xf6p', datetime.date(1996, 8, 14)),
#  (10281, u'Romero y tomillo', datetime.date(1996, 8, 14)),
#  (10282, u'Romero y tomillo', datetime.date(1996, 8, 15)),
#  (10283, u'LILA-Supermercado', datetime.date(1996, 8, 16)),
#  (10284, u'Lehmanns Marktstand', datetime.date(1996, 8, 19)),
#  (10285, u'QUICK-Stop', datetime.date(1996, 8, 20)),
#  (10286, u'QUICK-Stop', datetime.date(1996, 8, 21)),
#  (10287, u'Ricardo Adocicados', datetime.date(1996, 8, 22)),
#  (10288, u'Reggiani Caseifici', datetime.date(1996, 8, 23)),
#  (10289, u"B's Beverages", datetime.date(1996, 8, 26)),
#  (10290, u'Com\xe9rcio Mineiro', datetime.date(1996, 8, 27)),
#  (10291, u'Que Del\xedcia', datetime.date(1996, 8, 27)),
#  (10292, u'Tradi\xe7\xe3o Hipermercados', datetime.date(1996, 8, 28)),
#  (10293, u'Tortuga Restaurante', datetime.date(1996, 8, 29)),
#  (10294, u'Rattlesnake Canyon Grocery', datetime.date(1996, 8, 30)),
#  (10295, u'Vins et alcools Chevalier', datetime.date(1996, 9, 2)),
#  (10296, u'LILA-Supermercado', datetime.date(1996, 9, 3)),
#  (10297, u'Blondesddsl p\xe8re et fils', datetime.date(1996, 9, 4)),
#  (10298, u'Hungry Owl All-Night Grocers', datetime.date(1996, 9, 5)),
#  (10299, u'Ricardo Adocicados', datetime.date(1996, 9, 6)),
#  (10300, u'Magazzini Alimentari Riuniti', datetime.date(1996, 9, 9)),
#  (10301, u'Die Wandernde Kuh', datetime.date(1996, 9, 9)),
#  (10302, u'Supr\xeames d\xe9lices', datetime.date(1996, 9, 10)),
#  (10303, u'Godos Cocina T\xedpica', datetime.date(1996, 9, 11)),
#  (10304, u'Tortuga Restaurante', datetime.date(1996, 9, 12)),
#  (10305, u'Old World Delicatessen', datetime.date(1996, 9, 13)),
#  (10306, u'Romero y tomillo', datetime.date(1996, 9, 16)),
#  (10307, u'Lonesome Pine Restaurant', datetime.date(1996, 9, 17)),
#  (10308, u'Ana Trujillo Emparedados y helados', datetime.date(1996, 9, 18)),
#  (10309, u'Hungry Owl All-Night Grocers', datetime.date(1996, 9, 19)),
#  (10310, u'The Big Cheese', datetime.date(1996, 9, 20)),
#  (10311, u'Du monde entier', datetime.date(1996, 9, 20)),
#  (10312, u'Die Wandernde Kuh', datetime.date(1996, 9, 23)),
#  (10313, u'QUICK-Stop', datetime.date(1996, 9, 24)),
#  (10314, u'Rattlesnake Canyon Grocery', datetime.date(1996, 9, 25)),
#  (10315, u'Island Trading', datetime.date(1996, 9, 26)),
#  (10316, u'Rattlesnake Canyon Grocery', datetime.date(1996, 9, 27)),
#  (10317, u'Lonesome Pine Restaurant', datetime.date(1996, 9, 30)),
#  (10318, u'Island Trading', datetime.date(1996, 10, 1)),
#  (10319, u'Tortuga Restaurante', datetime.date(1996, 10, 2)),
#  (10320, u'Wartian Herkku', datetime.date(1996, 10, 3)),
#  (10321, u'Island Trading', datetime.date(1996, 10, 3)),
#  (10322, u'Pericles Comidas cl\xe1sicas', datetime.date(1996, 10, 4)),
#  (10323, u'K\xf6niglich Essen', datetime.date(1996, 10, 7)),
#  (10324, u'Save-a-lot Markets', datetime.date(1996, 10, 8)),
#  (10325, u'K\xf6niglich Essen', datetime.date(1996, 10, 9)),
#  (10326, u'B\xf3lido Comidas preparadas', datetime.date(1996, 10, 10)),
#  (10327, u'Folk och f\xe4 HB', datetime.date(1996, 10, 11)),
#  (10328, u'Furia Bacalhau e Frutos do Mar', datetime.date(1996, 10, 14)),
#  (10329, u'Split Rail Beer & Ale', datetime.date(1996, 10, 15)),
#  (10330, u'LILA-Supermercado', datetime.date(1996, 10, 16)),
#  (10331, u"Bon app'", datetime.date(1996, 10, 16)),
#  (10332, u'M\xe8re Paillarde', datetime.date(1996, 10, 17)),
#  (10333, u'Wartian Herkku', datetime.date(1996, 10, 18)),
#  (10334, u'Victuailles en stock', datetime.date(1996, 10, 21)),
#  (10335, u'Hungry Owl All-Night Grocers', datetime.date(1996, 10, 22)),
#  (10336, u'Princesa Isabel Vinhos', datetime.date(1996, 10, 23)),
#  (10337, u'Frankenversand', datetime.date(1996, 10, 24)),
#  (10338, u'Old World Delicatessen', datetime.date(1996, 10, 25)),
#  (10339, u'M\xe8re Paillarde', datetime.date(1996, 10, 28)),
#  (10340, u"Bon app'", datetime.date(1996, 10, 29)),
#  (10341, u'Simons bistro', datetime.date(1996, 10, 29)),
#  (10342, u'Frankenversand', datetime.date(1996, 10, 30)),
#  (10343, u'Lehmanns Marktstand', datetime.date(1996, 10, 31)),
#  (10344, u'White Clover Markets', datetime.date(1996, 11, 1)),
#  (10345, u'QUICK-Stop', datetime.date(1996, 11, 4)),
#  (10346, u'Rattlesnake Canyon Grocery', datetime.date(1996, 11, 5)),
#  (10347, u'Familia Arquibaldo', datetime.date(1996, 11, 6)),
#  (10348, u'Die Wandernde Kuh', datetime.date(1996, 11, 7)),
#  (10349, u'Split Rail Beer & Ale', datetime.date(1996, 11, 8)),
#  (10350, u"La maison d'Asie", datetime.date(1996, 11, 11)),
#  (10351, u'Ernst Handel', datetime.date(1996, 11, 11)),
#  (10352, u'Furia Bacalhau e Frutos do Mar', datetime.date(1996, 11, 12)),
#  (10353, u'Piccolo und mehr', datetime.date(1996, 11, 13)),
#  (10354, u'Pericles Comidas cl\xe1sicas', datetime.date(1996, 11, 14)),
#  (10355, u'Around the Horn', datetime.date(1996, 11, 15)),
#  (10356, u'Die Wandernde Kuh', datetime.date(1996, 11, 18)),
#  (10357, u'LILA-Supermercado', datetime.date(1996, 11, 19)),
#  (10358, u"La maison d'Asie", datetime.date(1996, 11, 20)),
#  (10359, u'Seven Seas Imports', datetime.date(1996, 11, 21)),
#  (10360, u'Blondesddsl p\xe8re et fils', datetime.date(1996, 11, 22)),
#  (10361, u'QUICK-Stop', datetime.date(1996, 11, 22)),
#  (10362, u"Bon app'", datetime.date(1996, 11, 25)),
#  (10363, u'Drachenblut Delikatessen', datetime.date(1996, 11, 26)),
#  (10364, u'Eastern Connection', datetime.date(1996, 11, 26)),
#  (10365, u'Antonio Moreno Taquer\xeda', datetime.date(1996, 11, 27)),
#  (10366, u'Galer\xeda del gastr\xf3nomo', datetime.date(1996, 11, 28)),
#  (10367, u'Vaffeljernet', datetime.date(1996, 11, 28)),
#  (10368, u'Ernst Handel', datetime.date(1996, 11, 29)),
#  (10369, u'Split Rail Beer & Ale', datetime.date(1996, 12, 2)),
#  (10370, u'Chop-suey Chinese', datetime.date(1996, 12, 3)),
#  (10371, u"La maison d'Asie", datetime.date(1996, 12, 3)),
#  (10372, u'Queen Cozinha', datetime.date(1996, 12, 4)),
#  (10373, u'Hungry Owl All-Night Grocers', datetime.date(1996, 12, 5)),
#  (10374, u'Wolski  Zajazd', datetime.date(1996, 12, 5)),
#  (10375, u'Hungry Coyote Import Store', datetime.date(1996, 12, 6)),
#  (10376, u'M\xe8re Paillarde', datetime.date(1996, 12, 9)),
#  (10377, u'Seven Seas Imports', datetime.date(1996, 12, 9)),
#  (10378, u'Folk och f\xe4 HB', datetime.date(1996, 12, 10)),
#  (10379, u'Que Del\xedcia', datetime.date(1996, 12, 11)),
#  (10380, u'Hungry Owl All-Night Grocers', datetime.date(1996, 12, 12)),
#  (10381, u'LILA-Supermercado', datetime.date(1996, 12, 12)),
#  (10382, u'Ernst Handel', datetime.date(1996, 12, 13)),
#  (10383, u'Around the Horn', datetime.date(1996, 12, 16)),
#  (10384, u'Berglunds snabbk\xf6p', datetime.date(1996, 12, 16)),
#  (10385, u'Split Rail Beer & Ale', datetime.date(1996, 12, 17)),
#  (10386, u'Familia Arquibaldo', datetime.date(1996, 12, 18)),
#  (10387, u'Sant\xe9 Gourmet', datetime.date(1996, 12, 18)),
#  (10388, u'Seven Seas Imports', datetime.date(1996, 12, 19)),
#  (10389, u'Bottom-Dollar Markets', datetime.date(1996, 12, 20)),
#  (10390, u'Ernst Handel', datetime.date(1996, 12, 23)),
#  (10391, u'Drachenblut Delikatessen', datetime.date(1996, 12, 23)),
#  (10392, u'Piccolo und mehr', datetime.date(1996, 12, 24)),
#  (10393, u'Save-a-lot Markets', datetime.date(1996, 12, 25)),
#  (10394, u'Hungry Coyote Import Store', datetime.date(1996, 12, 25)),
#  (10395, u'HILARION-Abastos', datetime.date(1996, 12, 26)),
#  (10396, u'Frankenversand', datetime.date(1996, 12, 27)),
#  (10397, u'Princesa Isabel Vinhos', datetime.date(1996, 12, 27)),
#  (10398, u'Save-a-lot Markets', datetime.date(1996, 12, 30)),
#  (10399, u'Vaffeljernet', datetime.date(1996, 12, 31)),
#  (10400, u'Eastern Connection', datetime.date(1997, 1, 1)),
#  (10401, u'Rattlesnake Canyon Grocery', datetime.date(1997, 1, 1)),
#  (10402, u'Ernst Handel', datetime.date(1997, 1, 2)),
#  (10403, u'Ernst Handel', datetime.date(1997, 1, 3)),
#  (10404, u'Magazzini Alimentari Riuniti', datetime.date(1997, 1, 3)),
#  (10405, u'LINO-Delicateses', datetime.date(1997, 1, 6)),
#  (10406, u'Queen Cozinha', datetime.date(1997, 1, 7)),
#  (10407, u'Ottilies K\xe4seladen', datetime.date(1997, 1, 7)),
#  (10408, u'Folies gourmandes', datetime.date(1997, 1, 8)),
#  (10409, u'Oc\xe9ano Atl\xe1ntico Ltda.', datetime.date(1997, 1, 9)),
#  (10410, u'Bottom-Dollar Markets', datetime.date(1997, 1, 10)),
#  (10411, u'Bottom-Dollar Markets', datetime.date(1997, 1, 10)),
#  (10412, u'Wartian Herkku', datetime.date(1997, 1, 13)),
#  (10413, u"La maison d'Asie", datetime.date(1997, 1, 14)),
#  (10414, u'Familia Arquibaldo', datetime.date(1997, 1, 14)),
#  (10415, u'Hungry Coyote Import Store', datetime.date(1997, 1, 15)),
#  (10416, u'Wartian Herkku', datetime.date(1997, 1, 16)),
#  (10417, u'Simons bistro', datetime.date(1997, 1, 16)),
#  (10418, u'QUICK-Stop', datetime.date(1997, 1, 17)),
#  (10419, u'Richter Supermarkt', datetime.date(1997, 1, 20)),
#  (10420, u'Wellington Importadora', datetime.date(1997, 1, 21)),
#  (10421, u'Que Del\xedcia', datetime.date(1997, 1, 21)),
#  (10422, u'Franchi S.p.A.', datetime.date(1997, 1, 22)),
#  (10423, u'Gourmet Lanchonetes', datetime.date(1997, 1, 23)),
#  (10424, u'M\xe8re Paillarde', datetime.date(1997, 1, 23)),
#  (10425, u"La maison d'Asie", datetime.date(1997, 1, 24)),
#  (10426, u'Galer\xeda del gastr\xf3nomo', datetime.date(1997, 1, 27)),
#  (10427, u'Piccolo und mehr', datetime.date(1997, 1, 27)),
#  (10428, u'Reggiani Caseifici', datetime.date(1997, 1, 28)),
#  (10429, u'Hungry Owl All-Night Grocers', datetime.date(1997, 1, 29)),
#  (10430, u'Ernst Handel', datetime.date(1997, 1, 30)),
#  (10431, u'Bottom-Dollar Markets', datetime.date(1997, 1, 30)),
#  (10432, u'Split Rail Beer & Ale', datetime.date(1997, 1, 31)),
#  (10433, u'Princesa Isabel Vinhos', datetime.date(1997, 2, 3)),
#  (10434, u'Folk och f\xe4 HB', datetime.date(1997, 2, 3)),
#  (10435, u'Consolidated Holdings', datetime.date(1997, 2, 4)),
#  (10436, u'Blondesddsl p\xe8re et fils', datetime.date(1997, 2, 5)),
#  (10437, u'Wartian Herkku', datetime.date(1997, 2, 5)),
#  (10438, u'Toms Spezialit\xe4ten', datetime.date(1997, 2, 6)),
#  (10439, u'M\xe8re Paillarde', datetime.date(1997, 2, 7)),
#  (10440, u'Save-a-lot Markets', datetime.date(1997, 2, 10)),
#  (10441, u'Old World Delicatessen', datetime.date(1997, 2, 10)),
#  (10442, u'Ernst Handel', datetime.date(1997, 2, 11)),
#  (10443, u'Reggiani Caseifici', datetime.date(1997, 2, 12)),
#  (10444, u'Berglunds snabbk\xf6p', datetime.date(1997, 2, 12)),
#  (10445, u'Berglunds snabbk\xf6p', datetime.date(1997, 2, 13)),
#  (10446, u'Toms Spezialit\xe4ten', datetime.date(1997, 2, 14)),
#  (10447, u'Ricardo Adocicados', datetime.date(1997, 2, 14)),
#  (10448, u'Rancho grande', datetime.date(1997, 2, 17)),
#  (10449, u'Blondesddsl p\xe8re et fils', datetime.date(1997, 2, 18)),
#  (10450, u'Victuailles en stock', datetime.date(1997, 2, 19)),
#  (10451, u'QUICK-Stop', datetime.date(1997, 2, 19)),
#  (10452, u'Save-a-lot Markets', datetime.date(1997, 2, 20)),
#  (10453, u'Around the Horn', datetime.date(1997, 2, 21)),
#  (10454, u"La maison d'Asie", datetime.date(1997, 2, 21)),
#  (10455, u'Wartian Herkku', datetime.date(1997, 2, 24)),
#  (10456, u'K\xf6niglich Essen', datetime.date(1997, 2, 25)),
#  (10457, u'K\xf6niglich Essen', datetime.date(1997, 2, 25)),
#  (10458, u'Supr\xeames d\xe9lices', datetime.date(1997, 2, 26)),
#  (10459, u'Victuailles en stock', datetime.date(1997, 2, 27)),
#  (10460, u'Folk och f\xe4 HB', datetime.date(1997, 2, 28)),
#  (10461, u'LILA-Supermercado', datetime.date(1997, 2, 28)),
#  (10462, u'Consolidated Holdings', datetime.date(1997, 3, 3)),
#  (10463, u'Supr\xeames d\xe9lices', datetime.date(1997, 3, 4)),
#  (10464, u'Furia Bacalhau e Frutos do Mar', datetime.date(1997, 3, 4)),
#  (10465, u'Vaffeljernet', datetime.date(1997, 3, 5)),
#  (10466, u'Com\xe9rcio Mineiro', datetime.date(1997, 3, 6)),
#  (10467, u'Magazzini Alimentari Riuniti', datetime.date(1997, 3, 6)),
#  (10468, u'K\xf6niglich Essen', datetime.date(1997, 3, 7)),
#  (10469, u'White Clover Markets', datetime.date(1997, 3, 10)),
#  (10470, u"Bon app'", datetime.date(1997, 3, 11)),
#  (10471, u"B's Beverages", datetime.date(1997, 3, 11)),
#  (10472, u'Seven Seas Imports', datetime.date(1997, 3, 12)),
#  (10473, u'Island Trading', datetime.date(1997, 3, 13)),
#  (10474, u'Pericles Comidas cl\xe1sicas', datetime.date(1997, 3, 13)),
#  (10475, u'Supr\xeames d\xe9lices', datetime.date(1997, 3, 14)),
#  (10476, u'HILARION-Abastos', datetime.date(1997, 3, 17)),
#  (10477, u'Princesa Isabel Vinhos', datetime.date(1997, 3, 17)),
#  (10478, u'Victuailles en stock', datetime.date(1997, 3, 18)),
#  (10479, u'Rattlesnake Canyon Grocery', datetime.date(1997, 3, 19)),
#  (10480, u'Folies gourmandes', datetime.date(1997, 3, 20)),
#  (10481, u'Ricardo Adocicados', datetime.date(1997, 3, 20)),
#  (10482, u'Lazy K Kountry Store', datetime.date(1997, 3, 21)),
#  (10483, u'White Clover Markets', datetime.date(1997, 3, 24)),
#  (10484, u"B's Beverages", datetime.date(1997, 3, 24)),
#  (10485, u'LINO-Delicateses', datetime.date(1997, 3, 25)),
#  (10486, u'HILARION-Abastos', datetime.date(1997, 3, 26)),
#  (10487, u'Queen Cozinha', datetime.date(1997, 3, 26)),
#  (10488, u'Frankenversand', datetime.date(1997, 3, 27)),
#  (10489, u'Piccolo und mehr', datetime.date(1997, 3, 28)),
#  (10490, u'HILARION-Abastos', datetime.date(1997, 3, 31)),
#  (10491, u'Furia Bacalhau e Frutos do Mar', datetime.date(1997, 3, 31)),
#  (10492, u'Bottom-Dollar Markets', datetime.date(1997, 4, 1)),
#  (10493, u"La maison d'Asie", datetime.date(1997, 4, 2)),
#  (10494, u'Com\xe9rcio Mineiro', datetime.date(1997, 4, 2)),
#  (10495, u'Laughing Bacchus Wine Cellars', datetime.date(1997, 4, 3)),
#  (10496, u'Tradi\xe7\xe3o Hipermercados', datetime.date(1997, 4, 4)),
#  (10497, u'Lehmanns Marktstand', datetime.date(1997, 4, 4)),
#  (10498, u'HILARION-Abastos', datetime.date(1997, 4, 7)),
#  (10499, u'LILA-Supermercado', datetime.date(1997, 4, 8)),
#  (10500, u"La maison d'Asie", datetime.date(1997, 4, 9)),
#  (10501, u'Blauer See Delikatessen', datetime.date(1997, 4, 9)),
#  (10502, u'Pericles Comidas cl\xe1sicas', datetime.date(1997, 4, 10)),
#  (10503, u'Hungry Owl All-Night Grocers', datetime.date(1997, 4, 11)),
#  (10504, u'White Clover Markets', datetime.date(1997, 4, 11)),
#  (10505, u'M\xe8re Paillarde', datetime.date(1997, 4, 14)),
#  (10506, u'K\xf6niglich Essen', datetime.date(1997, 4, 15)),
#  (10507, u'Antonio Moreno Taquer\xeda', datetime.date(1997, 4, 15)),
#  (10508, u'Ottilies K\xe4seladen', datetime.date(1997, 4, 16)),
#  (10509, u'Blauer See Delikatessen', datetime.date(1997, 4, 17)),
#  (10510, u'Save-a-lot Markets', datetime.date(1997, 4, 18)),
#  (10511, u"Bon app'", datetime.date(1997, 4, 18)),
#  (10512, u'Familia Arquibaldo', datetime.date(1997, 4, 21)),
#  (10513, u'Die Wandernde Kuh', datetime.date(1997, 4, 22)),
#  (10514, u'Ernst Handel', datetime.date(1997, 4, 22)),
#  (10515, u'QUICK-Stop', datetime.date(1997, 4, 23)),
#  (10516, u'Hungry Owl All-Night Grocers', datetime.date(1997, 4, 24)),
#  (10517, u'North/South', datetime.date(1997, 4, 24)),
#  (10518, u'Tortuga Restaurante', datetime.date(1997, 4, 25)),
#  (10519, u'Chop-suey Chinese', datetime.date(1997, 4, 28)),
#  (10520, u'Sant\xe9 Gourmet', datetime.date(1997, 4, 29)),
#  (10521, u'Cactus Comidas para llevar', datetime.date(1997, 4, 29)),
#  (10522, u'Lehmanns Marktstand', datetime.date(1997, 4, 30)),
#  (10523, u'Seven Seas Imports', datetime.date(1997, 5, 1)),
#  (10524, u'Berglunds snabbk\xf6p', datetime.date(1997, 5, 1)),
#  (10525, u"Bon app'", datetime.date(1997, 5, 2)),
#  (10526, u'Wartian Herkku', datetime.date(1997, 5, 5)),
#  (10527, u'QUICK-Stop', datetime.date(1997, 5, 5)),
#  (10528, u'Great Lakes Food Market', datetime.date(1997, 5, 6)),
#  (10529, u'Maison Dewey', datetime.date(1997, 5, 7)),
#  (10530, u'Piccolo und mehr', datetime.date(1997, 5, 8)),
#  (10531, u'Oc\xe9ano Atl\xe1ntico Ltda.', datetime.date(1997, 5, 8)),
#  (10532, u'Eastern Connection', datetime.date(1997, 5, 9)),
#  (10533, u'Folk och f\xe4 HB', datetime.date(1997, 5, 12)),
#  (10534, u'Lehmanns Marktstand', datetime.date(1997, 5, 12)),
#  (10535, u'Antonio Moreno Taquer\xeda', datetime.date(1997, 5, 13)),
#  (10536, u'Lehmanns Marktstand', datetime.date(1997, 5, 14)),
#  (10537, u'Richter Supermarkt', datetime.date(1997, 5, 14)),
#  (10538, u"B's Beverages", datetime.date(1997, 5, 15)),
#  (10539, u"B's Beverages", datetime.date(1997, 5, 16)),
#  (10540, u'QUICK-Stop', datetime.date(1997, 5, 19)),
#  (10541, u'Hanari Carnes', datetime.date(1997, 5, 19)),
#  (10542, u'K\xf6niglich Essen', datetime.date(1997, 5, 20)),
#  (10543, u'LILA-Supermercado', datetime.date(1997, 5, 21)),
#  (10544, u'Lonesome Pine Restaurant', datetime.date(1997, 5, 21)),
#  (10545, u'Lazy K Kountry Store', datetime.date(1997, 5, 22)),
#  (10546, u'Victuailles en stock', datetime.date(1997, 5, 23)),
#  (10547, u'Seven Seas Imports', datetime.date(1997, 5, 23)),
#  (10548, u'Toms Spezialit\xe4ten', datetime.date(1997, 5, 26)),
#  (10549, u'QUICK-Stop', datetime.date(1997, 5, 27)),
#  (10550, u'Godos Cocina T\xedpica', datetime.date(1997, 5, 28)),
#  (10551, u'Furia Bacalhau e Frutos do Mar', datetime.date(1997, 5, 28)),
#  (10552, u'HILARION-Abastos', datetime.date(1997, 5, 29)),
#  (10553, u'Wartian Herkku', datetime.date(1997, 5, 30)),
#  (10554, u'Ottilies K\xe4seladen', datetime.date(1997, 5, 30)),
#  (10555, u'Save-a-lot Markets', datetime.date(1997, 6, 2)),
#  (10556, u'Simons bistro', datetime.date(1997, 6, 3)),
#  (10557, u'Lehmanns Marktstand', datetime.date(1997, 6, 3)),
#  (10558, u'Around the Horn', datetime.date(1997, 6, 4)),
#  (10559, u'Blondesddsl p\xe8re et fils', datetime.date(1997, 6, 5)),
#  (10560, u'Frankenversand', datetime.date(1997, 6, 6)),
#  (10561, u'Folk och f\xe4 HB', datetime.date(1997, 6, 6)),
#  (10562, u'Reggiani Caseifici', datetime.date(1997, 6, 9)),
#  (10563, u'Ricardo Adocicados', datetime.date(1997, 6, 10)),
#  (10564, u'Rattlesnake Canyon Grocery', datetime.date(1997, 6, 10)),
#  (10565, u'M\xe8re Paillarde', datetime.date(1997, 6, 11)),
#  (10566, u'Blondesddsl p\xe8re et fils', datetime.date(1997, 6, 12)),
#  (10567, u'Hungry Owl All-Night Grocers', datetime.date(1997, 6, 12)),
#  (10568, u'Galer\xeda del gastr\xf3nomo', datetime.date(1997, 6, 13)),
#  (10569, u'Rattlesnake Canyon Grocery', datetime.date(1997, 6, 16)),
#  (10570, u'M\xe8re Paillarde', datetime.date(1997, 6, 17)),
#  (10571, u'Ernst Handel', datetime.date(1997, 6, 17)),
#  (10572, u'Berglunds snabbk\xf6p', datetime.date(1997, 6, 18)),
#  (10573, u'Antonio Moreno Taquer\xeda', datetime.date(1997, 6, 19)),
#  (10574, u"Trail's Head Gourmet Provisioners", datetime.date(1997, 6, 19)),
#  (10575, u'Morgenstern Gesundkost', datetime.date(1997, 6, 20)),
#  (10576, u'Tortuga Restaurante', datetime.date(1997, 6, 23)),
#  (10577, u"Trail's Head Gourmet Provisioners", datetime.date(1997, 6, 23)),
#  (10578, u"B's Beverages", datetime.date(1997, 6, 24)),
#  (10579, u"Let's Stop N Shop", datetime.date(1997, 6, 25)),
#  (10580, u'Ottilies K\xe4seladen', datetime.date(1997, 6, 26)),
#  (10581, u'Familia Arquibaldo', datetime.date(1997, 6, 26)),
#  (10582, u'Blauer See Delikatessen', datetime.date(1997, 6, 27)),
#  (10583, u'Wartian Herkku', datetime.date(1997, 6, 30)),
#  (10584, u'Blondesddsl p\xe8re et fils', datetime.date(1997, 6, 30)),
#  (10585, u'Wellington Importadora', datetime.date(1997, 7, 1)),
#  (10586, u'Reggiani Caseifici', datetime.date(1997, 7, 2)),
#  (10587, u'Que Del\xedcia', datetime.date(1997, 7, 2)),
#  (10588, u'QUICK-Stop', datetime.date(1997, 7, 3)),
#  (10589, u'Great Lakes Food Market', datetime.date(1997, 7, 4)),
#  (10590, u'M\xe8re Paillarde', datetime.date(1997, 7, 7)),
#  (10591, u'Vaffeljernet', datetime.date(1997, 7, 7)),
#  (10592, u'Lehmanns Marktstand', datetime.date(1997, 7, 8)),
#  (10593, u'Lehmanns Marktstand', datetime.date(1997, 7, 9)),
#  (10594, u'Old World Delicatessen', datetime.date(1997, 7, 9)),
#  (10595, u'Ernst Handel', datetime.date(1997, 7, 10)),
#  (10596, u'White Clover Markets', datetime.date(1997, 7, 11)),
#  (10597, u'Piccolo und mehr', datetime.date(1997, 7, 11)),
#  (10598, u'Rattlesnake Canyon Grocery', datetime.date(1997, 7, 14)),
#  (10599, u"B's Beverages", datetime.date(1997, 7, 15)),
#  (10600, u'Hungry Coyote Import Store', datetime.date(1997, 7, 16)),
#  (10601, u'HILARION-Abastos', datetime.date(1997, 7, 16)),
#  (10602, u'Vaffeljernet', datetime.date(1997, 7, 17)),
#  (10603, u'Save-a-lot Markets', datetime.date(1997, 7, 18)),
#  (10604, u'Furia Bacalhau e Frutos do Mar', datetime.date(1997, 7, 18)),
#  (10605, u'M\xe8re Paillarde', datetime.date(1997, 7, 21)),
#  (10606, u'Tradi\xe7\xe3o Hipermercados', datetime.date(1997, 7, 22)),
#  (10607, u'Save-a-lot Markets', datetime.date(1997, 7, 22)),
#  (10608, u'Toms Spezialit\xe4ten', datetime.date(1997, 7, 23)),
#  (10609, u'Du monde entier', datetime.date(1997, 7, 24)),
#  (10610, u"La maison d'Asie", datetime.date(1997, 7, 25)),
#  (10611, u'Wolski  Zajazd', datetime.date(1997, 7, 25)),
#  (10612, u'Save-a-lot Markets', datetime.date(1997, 7, 28)),
#  (10613, u'HILARION-Abastos', datetime.date(1997, 7, 29)),
#  (10614, u'Blauer See Delikatessen', datetime.date(1997, 7, 29)),
#  (10615, u'Wilman Kala', datetime.date(1997, 7, 30)),
#  (10616, u'Great Lakes Food Market', datetime.date(1997, 7, 31)),
#  (10617, u'Great Lakes Food Market', datetime.date(1997, 7, 31)),
#  (10618, u'M\xe8re Paillarde', datetime.date(1997, 8, 1)),
#  (10619, u'M\xe8re Paillarde', datetime.date(1997, 8, 4)),
#  (10620, u'Laughing Bacchus Wine Cellars', datetime.date(1997, 8, 5)),
#  (10621, u'Island Trading', datetime.date(1997, 8, 5)),
#  (10622, u'Ricardo Adocicados', datetime.date(1997, 8, 6)),
#  (10623, u'Frankenversand', datetime.date(1997, 8, 7)),
#  (10624, u'The Cracker Box', datetime.date(1997, 8, 7)),
#  (10625, u'Ana Trujillo Emparedados y helados', datetime.date(1997, 8, 8)),
#  (10626, u'Berglunds snabbk\xf6p', datetime.date(1997, 8, 11)),
#  (10627, u'Save-a-lot Markets', datetime.date(1997, 8, 11)),
#  (10628, u'Blondesddsl p\xe8re et fils', datetime.date(1997, 8, 12)),
#  (10629, u'Godos Cocina T\xedpica', datetime.date(1997, 8, 12)),
#  (10630, u'K\xf6niglich Essen', datetime.date(1997, 8, 13)),
#  (10631, u"La maison d'Asie", datetime.date(1997, 8, 14)),
#  (10632, u'Die Wandernde Kuh', datetime.date(1997, 8, 14)),
#  (10633, u'Ernst Handel', datetime.date(1997, 8, 15)),
#  (10634, u'Folies gourmandes', datetime.date(1997, 8, 15)),
#  (10635, u'Magazzini Alimentari Riuniti', datetime.date(1997, 8, 18)),
#  (10636, u'Wartian Herkku', datetime.date(1997, 8, 19)),
#  (10637, u'Queen Cozinha', datetime.date(1997, 8, 19)),
#  (10638, u'LINO-Delicateses', datetime.date(1997, 8, 20)),
#  (10639, u'Sant\xe9 Gourmet', datetime.date(1997, 8, 20)),
#  (10640, u'Die Wandernde Kuh', datetime.date(1997, 8, 21)),
#  (10641, u'HILARION-Abastos', datetime.date(1997, 8, 22)),
#  (10642, u'Simons bistro', datetime.date(1997, 8, 22)),
#  (10643, u'Alfreds Futterkiste', datetime.date(1997, 8, 25)),
#  (10644, u'Wellington Importadora', datetime.date(1997, 8, 25)),
#  (10645, u'Hanari Carnes', datetime.date(1997, 8, 26)),
#  (10646, u'Hungry Owl All-Night Grocers', datetime.date(1997, 8, 27)),
#  (10647, u'Que Del\xedcia', datetime.date(1997, 8, 27)),
#  (10648, u'Ricardo Adocicados', datetime.date(1997, 8, 28)),
#  (10649, u'Maison Dewey', datetime.date(1997, 8, 28)),
#  (10650, u'Familia Arquibaldo', datetime.date(1997, 8, 29)),
#  (10651, u'Die Wandernde Kuh', datetime.date(1997, 9, 1)),
#  (10652, u'Gourmet Lanchonetes', datetime.date(1997, 9, 1)),
#  (10653, u'Frankenversand', datetime.date(1997, 9, 2)),
#  (10654, u'Berglunds snabbk\xf6p', datetime.date(1997, 9, 2)),
#  (10655, u'Reggiani Caseifici', datetime.date(1997, 9, 3)),
#  (10656, u'Great Lakes Food Market', datetime.date(1997, 9, 4)),
#  (10657, u'Save-a-lot Markets', datetime.date(1997, 9, 4)),
#  (10658, u'QUICK-Stop', datetime.date(1997, 9, 5)),
#  (10659, u'Queen Cozinha', datetime.date(1997, 9, 5)),
#  (10660, u'Hungry Coyote Import Store', datetime.date(1997, 9, 8)),
#  (10661, u'Hungry Owl All-Night Grocers', datetime.date(1997, 9, 9)),
#  (10662, u'Lonesome Pine Restaurant', datetime.date(1997, 9, 9)),
#  (10663, u"Bon app'", datetime.date(1997, 9, 10)),
#  (10664, u'Furia Bacalhau e Frutos do Mar', datetime.date(1997, 9, 10)),
#  (10665, u'Lonesome Pine Restaurant', datetime.date(1997, 9, 11)),
#  (10666, u'Richter Supermarkt', datetime.date(1997, 9, 12)),
#  (10667, u'Ernst Handel', datetime.date(1997, 9, 12)),
#  (10668, u'Die Wandernde Kuh', datetime.date(1997, 9, 15)),
#  (10669, u'Simons bistro', datetime.date(1997, 9, 15)),
#  (10670, u'Frankenversand', datetime.date(1997, 9, 16)),
#  (10671, u'France restauration', datetime.date(1997, 9, 17)),
#  (10672, u'Berglunds snabbk\xf6p', datetime.date(1997, 9, 17)),
#  (10673, u'Wilman Kala', datetime.date(1997, 9, 18)),
#  (10674, u'Island Trading', datetime.date(1997, 9, 18)),
#  (10675, u'Frankenversand', datetime.date(1997, 9, 19)),
#  (10676, u'Tortuga Restaurante', datetime.date(1997, 9, 22)),
#  (10677, u'Antonio Moreno Taquer\xeda', datetime.date(1997, 9, 22)),
#  (10678, u'Save-a-lot Markets', datetime.date(1997, 9, 23)),
#  (10679, u'Blondesddsl p\xe8re et fils', datetime.date(1997, 9, 23)),
#  (10680, u'Old World Delicatessen', datetime.date(1997, 9, 24)),
#  (10681, u'Great Lakes Food Market', datetime.date(1997, 9, 25)),
#  (10682, u'Antonio Moreno Taquer\xeda', datetime.date(1997, 9, 25)),
#  (10683, u'Du monde entier', datetime.date(1997, 9, 26)),
#  (10684, u'Ottilies K\xe4seladen', datetime.date(1997, 9, 26)),
#  (10685, u'Gourmet Lanchonetes', datetime.date(1997, 9, 29)),
#  (10686, u'Piccolo und mehr', datetime.date(1997, 9, 30)),
#  (10687, u'Hungry Owl All-Night Grocers', datetime.date(1997, 9, 30)),
#  (10688, u'Vaffeljernet', datetime.date(1997, 10, 1)),
#  (10689, u'Berglunds snabbk\xf6p', datetime.date(1997, 10, 1)),
#  (10690, u'Hanari Carnes', datetime.date(1997, 10, 2)),
#  (10691, u'QUICK-Stop', datetime.date(1997, 10, 3)),
#  (10692, u'Alfreds Futterkiste', datetime.date(1997, 10, 3)),
#  (10693, u'White Clover Markets', datetime.date(1997, 10, 6)),
#  (10694, u'QUICK-Stop', datetime.date(1997, 10, 6)),
#  (10695, u'Wilman Kala', datetime.date(1997, 10, 7)),
#  (10696, u'White Clover Markets', datetime.date(1997, 10, 8)),
#  (10697, u'LINO-Delicateses', datetime.date(1997, 10, 8)),
#  (10698, u'Ernst Handel', datetime.date(1997, 10, 9)),
#  (10699, u'Morgenstern Gesundkost', datetime.date(1997, 10, 9)),
#  (10700, u'Save-a-lot Markets', datetime.date(1997, 10, 10)),
#  (10701, u'Hungry Owl All-Night Grocers', datetime.date(1997, 10, 13)),
#  (10702, u'Alfreds Futterkiste', datetime.date(1997, 10, 13)),
#  (10703, u'Folk och f\xe4 HB', datetime.date(1997, 10, 14)),
#  (10704, u'Queen Cozinha', datetime.date(1997, 10, 14)),
#  (10705, u'HILARION-Abastos', datetime.date(1997, 10, 15)),
#  (10706, u'Old World Delicatessen', datetime.date(1997, 10, 16)),
#  (10707, u'Around the Horn', datetime.date(1997, 10, 16)),
#  (10708, u'The Big Cheese', datetime.date(1997, 10, 17)),
#  (10709, u'Gourmet Lanchonetes', datetime.date(1997, 10, 17)),
#  (10710, u'Franchi S.p.A.', datetime.date(1997, 10, 20)),
#  (10711, u'Save-a-lot Markets', datetime.date(1997, 10, 21)),
#  (10712, u'Hungry Owl All-Night Grocers', datetime.date(1997, 10, 21)),
#  (10713, u'Save-a-lot Markets', datetime.date(1997, 10, 22)),
#  (10714, u'Save-a-lot Markets', datetime.date(1997, 10, 22)),
#  (10715, u"Bon app'", datetime.date(1997, 10, 23)),
#  (10716, u'Rancho grande', datetime.date(1997, 10, 24)),
#  (10717, u'Frankenversand', datetime.date(1997, 10, 24)),
#  (10718, u'K\xf6niglich Essen', datetime.date(1997, 10, 27)),
#  (10719, u"Let's Stop N Shop", datetime.date(1997, 10, 27)),
#  (10720, u'Que Del\xedcia', datetime.date(1997, 10, 28)),
#  (10721, u'QUICK-Stop', datetime.date(1997, 10, 29)),
#  (10722, u'Save-a-lot Markets', datetime.date(1997, 10, 29)),
#  (10723, u'White Clover Markets', datetime.date(1997, 10, 30)),
#  (10724, u'M\xe8re Paillarde', datetime.date(1997, 10, 30)),
#  (10725, u'Familia Arquibaldo', datetime.date(1997, 10, 31)),
#  (10726, u'Eastern Connection', datetime.date(1997, 11, 3)),
#  (10727, u'Reggiani Caseifici', datetime.date(1997, 11, 3)),
#  (10728, u'Queen Cozinha', datetime.date(1997, 11, 4)),
#  (10729, u'LINO-Delicateses', datetime.date(1997, 11, 4)),
#  (10730, u"Bon app'", datetime.date(1997, 11, 5)),
#  (10731, u'Chop-suey Chinese', datetime.date(1997, 11, 6)),
#  (10732, u"Bon app'", datetime.date(1997, 11, 6)),
#  (10733, u'Berglunds snabbk\xf6p', datetime.date(1997, 11, 7)),
#  (10734, u'Gourmet Lanchonetes', datetime.date(1997, 11, 7)),
#  (10735, u"Let's Stop N Shop", datetime.date(1997, 11, 10)),
#  (10736, u'Hungry Owl All-Night Grocers', datetime.date(1997, 11, 11)),
#  (10737, u'Vins et alcools Chevalier', datetime.date(1997, 11, 11)),
#  (10738, u'Sp\xe9cialit\xe9s du monde', datetime.date(1997, 11, 12)),
#  (10739, u'Vins et alcools Chevalier', datetime.date(1997, 11, 12)),
#  (10740, u'White Clover Markets', datetime.date(1997, 11, 13)),
#  (10741, u'Around the Horn', datetime.date(1997, 11, 14)),
#  (10742, u'Bottom-Dollar Markets', datetime.date(1997, 11, 14)),
#  (10743, u'Around the Horn', datetime.date(1997, 11, 17)),
#  (10744, u'Vaffeljernet', datetime.date(1997, 11, 17)),
#  (10745, u'QUICK-Stop', datetime.date(1997, 11, 18)),
#  (10746, u'Chop-suey Chinese', datetime.date(1997, 11, 19)),
#  (10747, u'Piccolo und mehr', datetime.date(1997, 11, 19)),
#  (10748, u'Save-a-lot Markets', datetime.date(1997, 11, 20)),
#  (10749, u'Island Trading', datetime.date(1997, 11, 20)),
#  (10750, u'Wartian Herkku', datetime.date(1997, 11, 21)),
#  (10751, u'Richter Supermarkt', datetime.date(1997, 11, 24)),
#  (10752, u'North/South', datetime.date(1997, 11, 24)),
#  (10753, u'Franchi S.p.A.', datetime.date(1997, 11, 25)),
#  (10754, u'Magazzini Alimentari Riuniti', datetime.date(1997, 11, 25)),
#  (10755, u"Bon app'", datetime.date(1997, 11, 26)),
#  (10756, u'Split Rail Beer & Ale', datetime.date(1997, 11, 27)),
#  (10757, u'Save-a-lot Markets', datetime.date(1997, 11, 27)),
#  (10758, u'Richter Supermarkt', datetime.date(1997, 11, 28)),
#  (10759, u'Ana Trujillo Emparedados y helados', datetime.date(1997, 11, 28)),
#  (10760, u'Maison Dewey', datetime.date(1997, 12, 1)),
#  (10761, u'Rattlesnake Canyon Grocery', datetime.date(1997, 12, 2)),
#  (10762, u'Folk och f\xe4 HB', datetime.date(1997, 12, 2)),
#  (10763, u'Folies gourmandes', datetime.date(1997, 12, 3)),
#  (10764, u'Ernst Handel', datetime.date(1997, 12, 3)),
#  (10765, u'QUICK-Stop', datetime.date(1997, 12, 4)),
#  (10766, u'Ottilies K\xe4seladen', datetime.date(1997, 12, 5)),
#  (10767, u'Supr\xeames d\xe9lices', datetime.date(1997, 12, 5)),
#  (10768, u'Around the Horn', datetime.date(1997, 12, 8)),
#  (10769, u'Vaffeljernet', datetime.date(1997, 12, 8)),
#  (10770, u'Hanari Carnes', datetime.date(1997, 12, 9)),
#  (10771, u'Ernst Handel', datetime.date(1997, 12, 10)),
#  (10772, u'Lehmanns Marktstand', datetime.date(1997, 12, 10)),
#  (10773, u'Ernst Handel', datetime.date(1997, 12, 11)),
#  (10774, u'Folk och f\xe4 HB', datetime.date(1997, 12, 11)),
#  (10775, u'The Cracker Box', datetime.date(1997, 12, 12)),
#  (10776, u'Ernst Handel', datetime.date(1997, 12, 15)),
#  (10777, u'Gourmet Lanchonetes', datetime.date(1997, 12, 15)),
#  (10778, u'Berglunds snabbk\xf6p', datetime.date(1997, 12, 16)),
#  (10779, u'Morgenstern Gesundkost', datetime.date(1997, 12, 16)),
#  (10780, u'LILA-Supermercado', datetime.date(1997, 12, 16)),
#  (10781, u'Wartian Herkku', datetime.date(1997, 12, 17)),
#  (10782, u'Cactus Comidas para llevar', datetime.date(1997, 12, 17)),
#  (10783, u'Hanari Carnes', datetime.date(1997, 12, 18)),
#  (10784, u'Magazzini Alimentari Riuniti', datetime.date(1997, 12, 18)),
#  (10785, u'GROSELLA-Restaurante', datetime.date(1997, 12, 18)),
#  (10786, u'Queen Cozinha', datetime.date(1997, 12, 19)),
#  (10787, u"La maison d'Asie", datetime.date(1997, 12, 19)),
#  (10788, u'QUICK-Stop', datetime.date(1997, 12, 22)),
#  (10789, u'Folies gourmandes', datetime.date(1997, 12, 22)),
#  (10790, u'Gourmet Lanchonetes', datetime.date(1997, 12, 22)),
#  (10791, u'Frankenversand', datetime.date(1997, 12, 23)),
#  (10792, u'Wolski  Zajazd', datetime.date(1997, 12, 23)),
#  (10793, u'Around the Horn', datetime.date(1997, 12, 24)),
#  (10794, u'Que Del\xedcia', datetime.date(1997, 12, 24)),
#  (10795, u'Ernst Handel', datetime.date(1997, 12, 24)),
#  (10796, u'HILARION-Abastos', datetime.date(1997, 12, 25)),
#  (10797, u'Drachenblut Delikatessen', datetime.date(1997, 12, 25)),
#  (10798, u'Island Trading', datetime.date(1997, 12, 26)),
#  (10799, u'K\xf6niglich Essen', datetime.date(1997, 12, 26)),
#  (10800, u'Seven Seas Imports', datetime.date(1997, 12, 26)),
#  (10801, u'B\xf3lido Comidas preparadas', datetime.date(1997, 12, 29)),
#  (10802, u'Simons bistro', datetime.date(1997, 12, 29)),
#  (10803, u'Wellington Importadora', datetime.date(1997, 12, 30)),
#  (10804, u'Seven Seas Imports', datetime.date(1997, 12, 30)),
#  (10805, u'The Big Cheese', datetime.date(1997, 12, 30)),
#  (10806, u'Victuailles en stock', datetime.date(1997, 12, 31)),
#  (10807, u'Franchi S.p.A.', datetime.date(1997, 12, 31)),
#  (10808, u'Old World Delicatessen', datetime.date(1998, 1, 1)),
#  (10809, u'Wellington Importadora', datetime.date(1998, 1, 1)),
#  (10810, u'Laughing Bacchus Wine Cellars', datetime.date(1998, 1, 1)),
#  (10811, u'LINO-Delicateses', datetime.date(1998, 1, 2)),
#  (10812, u'Reggiani Caseifici', datetime.date(1998, 1, 2)),
#  (10813, u'Ricardo Adocicados', datetime.date(1998, 1, 5)),
#  (10814, u'Victuailles en stock', datetime.date(1998, 1, 5)),
#  (10815, u'Save-a-lot Markets', datetime.date(1998, 1, 5)),
#  (10816, u'Great Lakes Food Market', datetime.date(1998, 1, 6)),
#  (10817, u'K\xf6niglich Essen', datetime.date(1998, 1, 6)),
#  (10818, u'Magazzini Alimentari Riuniti', datetime.date(1998, 1, 7)),
#  (10819, u'Cactus Comidas para llevar', datetime.date(1998, 1, 7)),
#  (10820, u'Rattlesnake Canyon Grocery', datetime.date(1998, 1, 7)),
#  (10821, u'Split Rail Beer & Ale', datetime.date(1998, 1, 8)),
#  (10822, u"Trail's Head Gourmet Provisioners", datetime.date(1998, 1, 8)),
#  (10823, u'LILA-Supermercado', datetime.date(1998, 1, 9)),
#  (10824, u'Folk och f\xe4 HB', datetime.date(1998, 1, 9)),
#  (10825, u'Drachenblut Delikatessen', datetime.date(1998, 1, 9)),
#  (10826, u'Blondesddsl p\xe8re et fils', datetime.date(1998, 1, 12)),
#  (10827, u"Bon app'", datetime.date(1998, 1, 12)),
#  (10828, u'Rancho grande', datetime.date(1998, 1, 13)),
#  (10829, u'Island Trading', datetime.date(1998, 1, 13)),
#  (10830, u'Tradi\xe7\xe3o Hipermercados', datetime.date(1998, 1, 13)),
#  (10831, u'Sant\xe9 Gourmet', datetime.date(1998, 1, 14)),
#  (10832, u"La maison d'Asie", datetime.date(1998, 1, 14)),
#  (10833, u'Ottilies K\xe4seladen', datetime.date(1998, 1, 15)),
#  (10834, u'Tradi\xe7\xe3o Hipermercados', datetime.date(1998, 1, 15)),
#  (10835, u'Alfreds Futterkiste', datetime.date(1998, 1, 15)),
#  (10836, u'Ernst Handel', datetime.date(1998, 1, 16)),
#  (10837, u'Berglunds snabbk\xf6p', datetime.date(1998, 1, 16)),
#  (10838, u'LINO-Delicateses', datetime.date(1998, 1, 19)),
#  (10839, u'Tradi\xe7\xe3o Hipermercados', datetime.date(1998, 1, 19)),
#  (10840, u'LINO-Delicateses', datetime.date(1998, 1, 19)),
#  (10841, u'Supr\xeames d\xe9lices', datetime.date(1998, 1, 20)),
#  (10842, u'Tortuga Restaurante', datetime.date(1998, 1, 20)),
#  (10843, u'Victuailles en stock', datetime.date(1998, 1, 21)),
#  (10844, u'Piccolo und mehr', datetime.date(1998, 1, 21)),
#  (10845, u'QUICK-Stop', datetime.date(1998, 1, 21)),
#  (10846, u'Supr\xeames d\xe9lices', datetime.date(1998, 1, 22)),
#  (10847, u'Save-a-lot Markets', datetime.date(1998, 1, 22)),
#  (10848, u'Consolidated Holdings', datetime.date(1998, 1, 23)),
#  (10849, u'K\xf6niglich Essen', datetime.date(1998, 1, 23)),
#  (10850, u'Victuailles en stock', datetime.date(1998, 1, 23)),
#  (10851, u'Ricardo Adocicados', datetime.date(1998, 1, 26)),
#  (10852, u'Rattlesnake Canyon Grocery', datetime.date(1998, 1, 26)),
#  (10853, u'Blauer See Delikatessen', datetime.date(1998, 1, 27)),
#  (10854, u'Ernst Handel', datetime.date(1998, 1, 27)),
#  (10855, u'Old World Delicatessen', datetime.date(1998, 1, 27)),
#  (10856, u'Antonio Moreno Taquer\xeda', datetime.date(1998, 1, 28)),
#  (10857, u'Berglunds snabbk\xf6p', datetime.date(1998, 1, 28)),
#  (10858, u"La corne d'abondance", datetime.date(1998, 1, 29)),
#  (10859, u'Frankenversand', datetime.date(1998, 1, 29)),
#  (10860, u'France restauration', datetime.date(1998, 1, 29)),
#  (10861, u'White Clover Markets', datetime.date(1998, 1, 30)),
#  (10862, u'Lehmanns Marktstand', datetime.date(1998, 1, 30)),
#  (10863, u'HILARION-Abastos', datetime.date(1998, 2, 2)),
#  (10864, u'Around the Horn', datetime.date(1998, 2, 2)),
#  (10865, u'QUICK-Stop', datetime.date(1998, 2, 2)),
#  (10866, u'Berglunds snabbk\xf6p', datetime.date(1998, 2, 3)),
#  (10867, u'Lonesome Pine Restaurant', datetime.date(1998, 2, 3)),
#  (10868, u'Queen Cozinha', datetime.date(1998, 2, 4)),
#  (10869, u'Seven Seas Imports', datetime.date(1998, 2, 4)),
#  (10870, u'Wolski  Zajazd', datetime.date(1998, 2, 4)),
#  (10871, u"Bon app'", datetime.date(1998, 2, 5)),
#  (10872, u'Godos Cocina T\xedpica', datetime.date(1998, 2, 5)),
#  (10873, u'Wilman Kala', datetime.date(1998, 2, 6)),
#  (10874, u'Godos Cocina T\xedpica', datetime.date(1998, 2, 6)),
#  (10875, u'Berglunds snabbk\xf6p', datetime.date(1998, 2, 6)),
#  (10876, u"Bon app'", datetime.date(1998, 2, 9)),
#  (10877, u'Ricardo Adocicados', datetime.date(1998, 2, 9)),
#  (10878, u'QUICK-Stop', datetime.date(1998, 2, 10)),
#  (10879, u'Wilman Kala', datetime.date(1998, 2, 10)),
#  (10880, u'Folk och f\xe4 HB', datetime.date(1998, 2, 10)),
#  (10881, u'Cactus Comidas para llevar', datetime.date(1998, 2, 11)),
#  (10882, u'Save-a-lot Markets', datetime.date(1998, 2, 11)),
#  (10883, u'Lonesome Pine Restaurant', datetime.date(1998, 2, 12)),
#  (10884, u"Let's Stop N Shop", datetime.date(1998, 2, 12)),
#  (10885, u'Supr\xeames d\xe9lices', datetime.date(1998, 2, 12)),
#  (10886, u'Hanari Carnes', datetime.date(1998, 2, 13)),
#  (10887, u'Galer\xeda del gastr\xf3nomo', datetime.date(1998, 2, 13)),
#  (10888, u'Godos Cocina T\xedpica', datetime.date(1998, 2, 16)),
#  (10889, u'Rattlesnake Canyon Grocery', datetime.date(1998, 2, 16)),
#  (10890, u'Du monde entier', datetime.date(1998, 2, 16)),
#  (10891, u'Lehmanns Marktstand', datetime.date(1998, 2, 17)),
#  (10892, u'Maison Dewey', datetime.date(1998, 2, 17)),
#  (10893, u'K\xf6niglich Essen', datetime.date(1998, 2, 18)),
#  (10894, u'Save-a-lot Markets', datetime.date(1998, 2, 18)),
#  (10895, u'Ernst Handel', datetime.date(1998, 2, 18)),
#  (10896, u'Maison Dewey', datetime.date(1998, 2, 19)),
#  (10897, u'Hungry Owl All-Night Grocers', datetime.date(1998, 2, 19)),
#  (10898, u'Oc\xe9ano Atl\xe1ntico Ltda.', datetime.date(1998, 2, 20)),
#  (10899, u'LILA-Supermercado', datetime.date(1998, 2, 20)),
#  (10900, u'Wellington Importadora', datetime.date(1998, 2, 20)),
#  (10901, u'HILARION-Abastos', datetime.date(1998, 2, 23)),
#  (10902, u'Folk och f\xe4 HB', datetime.date(1998, 2, 23)),
#  (10903, u'Hanari Carnes', datetime.date(1998, 2, 24)),
#  (10904, u'White Clover Markets', datetime.date(1998, 2, 24)),
#  (10905, u'Wellington Importadora', datetime.date(1998, 2, 24)),
#  (10906, u'Wolski  Zajazd', datetime.date(1998, 2, 25)),
#  (10907, u'Sp\xe9cialit\xe9s du monde', datetime.date(1998, 2, 25)),
#  (10908, u'Reggiani Caseifici', datetime.date(1998, 2, 26)),
#  (10909, u'Sant\xe9 Gourmet', datetime.date(1998, 2, 26)),
#  (10910, u'Wilman Kala', datetime.date(1998, 2, 26)),
#  (10911, u'Godos Cocina T\xedpica', datetime.date(1998, 2, 26)),
#  (10912, u'Hungry Owl All-Night Grocers', datetime.date(1998, 2, 26)),
#  (10913, u'Queen Cozinha', datetime.date(1998, 2, 26)),
#  (10914, u'Queen Cozinha', datetime.date(1998, 2, 27)),
#  (10915, u'Tortuga Restaurante', datetime.date(1998, 2, 27)),
#  (10916, u'Rancho grande', datetime.date(1998, 2, 27)),
#  (10917, u'Romero y tomillo', datetime.date(1998, 3, 2)),
#  (10918, u'Bottom-Dollar Markets', datetime.date(1998, 3, 2)),
#  (10919, u'LINO-Delicateses', datetime.date(1998, 3, 2)),
#  (10920, u'Around the Horn', datetime.date(1998, 3, 3)),
#  (10921, u'Vaffeljernet', datetime.date(1998, 3, 3)),
#  (10922, u'Hanari Carnes', datetime.date(1998, 3, 3)),
#  (10923, u"La maison d'Asie", datetime.date(1998, 3, 3)),
#  (10924, u'Berglunds snabbk\xf6p', datetime.date(1998, 3, 4)),
#  (10925, u'Hanari Carnes', datetime.date(1998, 3, 4)),
#  (10926, u'Ana Trujillo Emparedados y helados', datetime.date(1998, 3, 4)),
#  (10927, u"La corne d'abondance", datetime.date(1998, 3, 5)),
#  (10928, u'Galer\xeda del gastr\xf3nomo', datetime.date(1998, 3, 5)),
#  (10929, u'Frankenversand', datetime.date(1998, 3, 5)),
#  (10930, u'Supr\xeames d\xe9lices', datetime.date(1998, 3, 6)),
#  (10931, u'Richter Supermarkt', datetime.date(1998, 3, 6)),
#  (10932, u"Bon app'", datetime.date(1998, 3, 6)),
#  (10933, u'Island Trading', datetime.date(1998, 3, 6)),
#  (10934, u'Lehmanns Marktstand', datetime.date(1998, 3, 9)),
#  (10935, u'Wellington Importadora', datetime.date(1998, 3, 9)),
#  (10936, u'Great Lakes Food Market', datetime.date(1998, 3, 9)),
#  (10937, u'Cactus Comidas para llevar', datetime.date(1998, 3, 10)),
#  (10938, u'QUICK-Stop', datetime.date(1998, 3, 10)),
#  (10939, u'Magazzini Alimentari Riuniti', datetime.date(1998, 3, 10)),
#  (10940, u"Bon app'", datetime.date(1998, 3, 11)),
#  (10941, u'Save-a-lot Markets', datetime.date(1998, 3, 11)),
#  (10942, u'Reggiani Caseifici', datetime.date(1998, 3, 11)),
#  (10943, u"B's Beverages", datetime.date(1998, 3, 11)),
#  (10944, u'Bottom-Dollar Markets', datetime.date(1998, 3, 12)),
#  (10945, u'Morgenstern Gesundkost', datetime.date(1998, 3, 12)),
#  (10946, u'Vaffeljernet', datetime.date(1998, 3, 12)),
#  (10947, u"B's Beverages", datetime.date(1998, 3, 13)),
#  (10948, u'Godos Cocina T\xedpica', datetime.date(1998, 3, 13)),
#  (10949, u'Bottom-Dollar Markets', datetime.date(1998, 3, 13)),
#  (10950, u'Magazzini Alimentari Riuniti', datetime.date(1998, 3, 16)),
#  (10951, u'Richter Supermarkt', datetime.date(1998, 3, 16)),
#  (10952, u'Alfreds Futterkiste', datetime.date(1998, 3, 16)),
#  (10953, u'Around the Horn', datetime.date(1998, 3, 16)),
#  (10954, u'LINO-Delicateses', datetime.date(1998, 3, 17)),
#  (10955, u'Folk och f\xe4 HB', datetime.date(1998, 3, 17)),
#  (10956, u'Blauer See Delikatessen', datetime.date(1998, 3, 17)),
#  (10957, u'HILARION-Abastos', datetime.date(1998, 3, 18)),
#  (10958, u'Oc\xe9ano Atl\xe1ntico Ltda.', datetime.date(1998, 3, 18)),
#  (10959, u'Gourmet Lanchonetes', datetime.date(1998, 3, 18)),
#  (10960, u'HILARION-Abastos', datetime.date(1998, 3, 19)),
#  (10961, u'Queen Cozinha', datetime.date(1998, 3, 19)),
#  (10962, u'QUICK-Stop', datetime.date(1998, 3, 19)),
#  (10963, u'Furia Bacalhau e Frutos do Mar', datetime.date(1998, 3, 19)),
#  (10964, u'Sp\xe9cialit\xe9s du monde', datetime.date(1998, 3, 20)),
#  (10965, u'Old World Delicatessen', datetime.date(1998, 3, 20)),
#  (10966, u'Chop-suey Chinese', datetime.date(1998, 3, 20)),
#  (10967, u'Toms Spezialit\xe4ten', datetime.date(1998, 3, 23)),
#  (10968, u'Ernst Handel', datetime.date(1998, 3, 23)),
#  (10969, u'Com\xe9rcio Mineiro', datetime.date(1998, 3, 23)),
#  (10970, u'B\xf3lido Comidas preparadas', datetime.date(1998, 3, 24)),
#  (10971, u'France restauration', datetime.date(1998, 3, 24)),
#  (10972, u"La corne d'abondance", datetime.date(1998, 3, 24)),
#  (10973, u"La corne d'abondance", datetime.date(1998, 3, 24)),
#  (10974, u'Split Rail Beer & Ale', datetime.date(1998, 3, 25)),
#  (10975, u'Bottom-Dollar Markets', datetime.date(1998, 3, 25)),
#  (10976, u'HILARION-Abastos', datetime.date(1998, 3, 25)),
#  (10977, u'Folk och f\xe4 HB', datetime.date(1998, 3, 26)),
#  (10978, u'Maison Dewey', datetime.date(1998, 3, 26)),
#  (10979, u'Ernst Handel', datetime.date(1998, 3, 26)),
#  (10980, u'Folk och f\xe4 HB', datetime.date(1998, 3, 27)),
#  (10981, u'Hanari Carnes', datetime.date(1998, 3, 27)),
#  (10982, u'Bottom-Dollar Markets', datetime.date(1998, 3, 27)),
#  (10983, u'Save-a-lot Markets', datetime.date(1998, 3, 27)),
#  (10984, u'Save-a-lot Markets', datetime.date(1998, 3, 30)),
#  (10985, u'Hungry Owl All-Night Grocers', datetime.date(1998, 3, 30)),
#  (10986, u'Oc\xe9ano Atl\xe1ntico Ltda.', datetime.date(1998, 3, 30)),
#  (10987, u'Eastern Connection', datetime.date(1998, 3, 31)),
#  (10988, u'Rattlesnake Canyon Grocery', datetime.date(1998, 3, 31)),
#  (10989, u'Que Del\xedcia', datetime.date(1998, 3, 31)),
#  (10990, u'Ernst Handel', datetime.date(1998, 4, 1)),
#  (10991, u'QUICK-Stop', datetime.date(1998, 4, 1)),
#  (10992, u'The Big Cheese', datetime.date(1998, 4, 1)),
#  (10993, u'Folk och f\xe4 HB', datetime.date(1998, 4, 1)),
#  (10994, u'Vaffeljernet', datetime.date(1998, 4, 2)),
#  (10995, u'Pericles Comidas cl\xe1sicas', datetime.date(1998, 4, 2)),
#  (10996, u'QUICK-Stop', datetime.date(1998, 4, 2)),
#  (10997, u'LILA-Supermercado', datetime.date(1998, 4, 3)),
#  (10998, u'Wolski  Zajazd', datetime.date(1998, 4, 3)),
#  (10999, u'Ottilies K\xe4seladen', datetime.date(1998, 4, 3)),
#  (11000, u'Rattlesnake Canyon Grocery', datetime.date(1998, 4, 6)),
#  (11001, u'Folk och f\xe4 HB', datetime.date(1998, 4, 6)),
#  (11002, u'Save-a-lot Markets', datetime.date(1998, 4, 6)),
#  (11003, u'The Cracker Box', datetime.date(1998, 4, 6)),
#  (11004, u'Maison Dewey', datetime.date(1998, 4, 7)),
#  (11005, u'Wilman Kala', datetime.date(1998, 4, 7)),
#  (11006, u'Great Lakes Food Market', datetime.date(1998, 4, 7)),
#  (11007, u'Princesa Isabel Vinhos', datetime.date(1998, 4, 8)),
#  (11008, u'Ernst Handel', datetime.date(1998, 4, 8)),
#  (11009, u'Godos Cocina T\xedpica', datetime.date(1998, 4, 8)),
#  (11010, u'Reggiani Caseifici', datetime.date(1998, 4, 9)),
#  (11011, u'Alfreds Futterkiste', datetime.date(1998, 4, 9)),
#  (11012, u'Frankenversand', datetime.date(1998, 4, 9)),
#  (11013, u'Romero y tomillo', datetime.date(1998, 4, 9)),
#  (11014, u'LINO-Delicateses', datetime.date(1998, 4, 10)),
#  (11015, u'Sant\xe9 Gourmet', datetime.date(1998, 4, 10)),
#  (11016, u'Around the Horn', datetime.date(1998, 4, 10)),
#  (11017, u'Ernst Handel', datetime.date(1998, 4, 13)),
#  (11018, u'Lonesome Pine Restaurant', datetime.date(1998, 4, 13)),
#  (11019, u'Rancho grande', datetime.date(1998, 4, 13)),
#  (11020, u'Ottilies K\xe4seladen', datetime.date(1998, 4, 14)),
#  (11021, u'QUICK-Stop', datetime.date(1998, 4, 14)),
#  (11022, u'Hanari Carnes', datetime.date(1998, 4, 14)),
#  (11023, u"B's Beverages", datetime.date(1998, 4, 14)),
#  (11024, u'Eastern Connection', datetime.date(1998, 4, 15)),
#  (11025, u'Wartian Herkku', datetime.date(1998, 4, 15)),
#  (11026, u'Franchi S.p.A.', datetime.date(1998, 4, 15)),
#  (11027, u'Bottom-Dollar Markets', datetime.date(1998, 4, 16)),
#  (11028, u'K\xf6niglich Essen', datetime.date(1998, 4, 16)),
#  (11029, u'Chop-suey Chinese', datetime.date(1998, 4, 16)),
#  (11030, u'Save-a-lot Markets', datetime.date(1998, 4, 17)),
#  (11031, u'Save-a-lot Markets', datetime.date(1998, 4, 17)),
#  (11032, u'White Clover Markets', datetime.date(1998, 4, 17)),
#  (11033, u'Richter Supermarkt', datetime.date(1998, 4, 17)),
#  (11034, u'Old World Delicatessen', datetime.date(1998, 4, 20)),
#  (11035, u'Supr\xeames d\xe9lices', datetime.date(1998, 4, 20)),
#  (11036, u'Drachenblut Delikatessen', datetime.date(1998, 4, 20)),
#  (11037, u'Godos Cocina T\xedpica', datetime.date(1998, 4, 21)),
#  (11038, u'Supr\xeames d\xe9lices', datetime.date(1998, 4, 21)),
#  (11039, u'LINO-Delicateses', datetime.date(1998, 4, 21)),
#  (11040, u'Great Lakes Food Market', datetime.date(1998, 4, 22)),
#  (11041, u'Chop-suey Chinese', datetime.date(1998, 4, 22)),
#  (11042, u'Com\xe9rcio Mineiro', datetime.date(1998, 4, 22)),
#  (11043, u'Sp\xe9cialit\xe9s du monde', datetime.date(1998, 4, 22)),
#  (11044, u'Wolski  Zajazd', datetime.date(1998, 4, 23)),
#  (11045, u'Bottom-Dollar Markets', datetime.date(1998, 4, 23)),
#  (11046, u'Die Wandernde Kuh', datetime.date(1998, 4, 23)),
#  (11047, u'Eastern Connection', datetime.date(1998, 4, 24)),
#  (11048, u'Bottom-Dollar Markets', datetime.date(1998, 4, 24)),
#  (11049, u'Gourmet Lanchonetes', datetime.date(1998, 4, 24)),
#  (11050, u'Folk och f\xe4 HB', datetime.date(1998, 4, 27)),
#  (11051, u"La maison d'Asie", datetime.date(1998, 4, 27)),
#  (11052, u'Hanari Carnes', datetime.date(1998, 4, 27)),
#  (11053, u'Piccolo und mehr', datetime.date(1998, 4, 27)),
#  (11054, u'Cactus Comidas para llevar', datetime.date(1998, 4, 28)),
#  (11055, u'HILARION-Abastos', datetime.date(1998, 4, 28)),
#  (11056, u'Eastern Connection', datetime.date(1998, 4, 28)),
#  (11057, u'North/South', datetime.date(1998, 4, 29)),
#  (11058, u'Blauer See Delikatessen', datetime.date(1998, 4, 29)),
#  (11059, u'Ricardo Adocicados', datetime.date(1998, 4, 29)),
#  (11060, u'Franchi S.p.A.', datetime.date(1998, 4, 30)),
#  (11061, u'Great Lakes Food Market', datetime.date(1998, 4, 30)),
#  (11062, u'Reggiani Caseifici', datetime.date(1998, 4, 30)),
#  (11063, u'Hungry Owl All-Night Grocers', datetime.date(1998, 4, 30)),
#  (11064, u'Save-a-lot Markets', datetime.date(1998, 5, 1)),
#  (11065, u'LILA-Supermercado', datetime.date(1998, 5, 1)),
#  (11066, u'White Clover Markets', datetime.date(1998, 5, 1)),
#  (11067, u'Drachenblut Delikatessen', datetime.date(1998, 5, 4)),
#  (11068, u'Queen Cozinha', datetime.date(1998, 5, 4)),
#  (11069, u'Tortuga Restaurante', datetime.date(1998, 5, 4)),
#  (11070, u'Lehmanns Marktstand', datetime.date(1998, 5, 5)),
#  (11071, u'LILA-Supermercado', datetime.date(1998, 5, 5)),
#  (11072, u'Ernst Handel', datetime.date(1998, 5, 5)),
#  (11073, u'Pericles Comidas cl\xe1sicas', datetime.date(1998, 5, 5)),
#  (11074, u'Simons bistro', datetime.date(1998, 5, 6)),
#  (11075, u'Richter Supermarkt', datetime.date(1998, 5, 6)),
#  (11076, u"Bon app'", datetime.date(1998, 5, 6)),
#  (11077, u'Rattlesnake Canyon Grocery', datetime.date(1998, 5, 6))]

# %% [markdown]
# There are several types of join operations.
#
# - INNER JOIN: Returns all rows when there is at least one match in BOTH tables
# - LEFT JOIN: Return all rows from the left table, and the matched rows from the right table
# - RIGHT JOIN: Return all rows from the right table, and the matched rows from the left table
# - FULL JOIN: Return all rows when there is a match in ONE of the tables
#
# (This is all rooted in [Relational Algebra](https://en.wikipedia.org/wiki/Relational_algebra). We won't go into it here, but it's an interesting topic.)

# %% [markdown]
# ![Joins](./assets/images/joins.gif)
#
# > Check: stop and jot! Can you annotate this diagram with examples of when you would use each? If you need a concrete starting point, imagine you have a table of Q1 orders for your company, and a second table of Q1's new sales leads.

# %% [markdown]
# ### Left Join
#
# The LEFT JOIN keyword returns all rows from the left table (table1), with the matching rows in the right table (table2). The right-hand result is NULL when the left-hand rows do not have a match.
#
#
# #### Left Join Syntax
# ```sql
# SELECT column_name(s)
# FROM table1
# LEFT JOIN table2
# ON table1.column_name=table2.column_name;
# ```
#
# > **Check:** Consider the JOIN we performed between `orders` and `customers`. Which column might contain NULL values in the joined table if we performed a LEFT JOIN?

# %% [markdown]
# ### Right Join
#
# Similarly, the RIGHT JOIN keyword returns all rows from the right table (table2), with the matching rows in the left table (table1). The result is NULL in the left side when there is no match.
#
# #### Right Join Syntax
# ```sql
# SELECT column_name(s)
# FROM table1
# RIGHT JOIN table2
# ON table1.column_name=table2.column_name;
# ```
# > **Check:** What use cases can you imagine for a RIGHT JOIN?

# %% [markdown]
# ### Full (outer) Join
#
# The FULL OUTER JOIN keyword returns all rows from the left table (table1) and from the right table (table2). The FULL OUTER JOIN keyword combines the result of both LEFT and RIGHT joins. In this case we could have NULL values on both sides.
#
# #### Full Join Syntax
#
# ```sql
# SELECT column_name(s)
# FROM table1
# FULL OUTER JOIN table2
# ON table1.column_name=table2.column_name;
# ```

# %% [markdown]
# <a name="guided-practice"></a>
# ## Guided Practice: Joins (15 mins)
#
# - How many products per category does the catalog contain? Print the answer with the `CategoryName`, and `Count`.

# %%
# %%sql
#
# SELECT * INTO temp
# FROM categories
# ALTER temp
# DROP COLUMN "Picture"
# SELECT * FROM temp
# DROP TABLE temp;
# Out:
# (psycopg2.ProgrammingError) syntax error at or near "temp"
# LINE 3: ALTER temp
#               ^
#  [SQL: 'SELECT * INTO temp \nFROM categories\nALTER temp\nDROP COLUMN "Picture"\nSELECT * FROM temp\nDROP TABLE temp;']

# %%
# %%sql
#
# SELECT * FROM products
# Out:
# 77 rows affected.
# [(1, u'Chai', 8, 1, u'10 boxes x 30 bags', 18.0, 39, 0, 10, 1),
#  (2, u'Chang', 1, 1, u'24 - 12 oz bottles', 19.0, 17, 40, 25, 1),
#  (3, u'Aniseed Syrup', 1, 2, u'12 - 550 ml bottles', 10.0, 13, 70, 25, 0),
#  (4, u"Chef Anton's Cajun Seasoning", 2, 2, u'48 - 6 oz jars', 22.0, 53, 0, 0, 0),
#  (5, u"Chef Anton's Gumbo Mix", 2, 2, u'36 boxes', 21.35, 0, 0, 0, 1),
#  (6, u"Grandma's Boysenberry Spread", 3, 2, u'12 - 8 oz jars', 25.0, 120, 0, 25, 0),
#  (7, u"Uncle Bob's Organic Dried Pears", 3, 7, u'12 - 1 lb pkgs.', 30.0, 15, 0, 10, 0),
#  (8, u'Northwoods Cranberry Sauce', 3, 2, u'12 - 12 oz jars', 40.0, 6, 0, 0, 0),
#  (9, u'Mishi Kobe Niku', 4, 6, u'18 - 500 g pkgs.', 97.0, 29, 0, 0, 1),
#  (10, u'Ikura', 4, 8, u'12 - 200 ml jars', 31.0, 31, 0, 0, 0),
#  (11, u'Queso Cabrales', 5, 4, u'1 kg pkg.', 21.0, 22, 30, 30, 0),
#  (12, u'Queso Manchego La Pastora', 5, 4, u'10 - 500 g pkgs.', 38.0, 86, 0, 0, 0),
#  (13, u'Konbu', 6, 8, u'2 kg box', 6.0, 24, 0, 5, 0),
#  (14, u'Tofu', 6, 7, u'40 - 100 g pkgs.', 23.25, 35, 0, 0, 0),
#  (15, u'Genen Shouyu', 6, 2, u'24 - 250 ml bottles', 13.0, 39, 0, 5, 0),
#  (16, u'Pavlova', 7, 3, u'32 - 500 g boxes', 17.45, 29, 0, 10, 0),
#  (17, u'Alice Mutton', 7, 6, u'20 - 1 kg tins', 39.0, 0, 0, 0, 1),
#  (18, u'Carnarvon Tigers', 7, 8, u'16 kg pkg.', 62.5, 42, 0, 0, 0),
#  (19, u'Teatime Chocolate Biscuits', 8, 3, u'10 boxes x 12 pieces', 9.2, 25, 0, 5, 0),
#  (20, u"Sir Rodney's Marmalade", 8, 3, u'30 gift boxes', 81.0, 40, 0, 0, 0),
#  (21, u"Sir Rodney's Scones", 8, 3, u'24 pkgs. x 4 pieces', 10.0, 3, 40, 5, 0),
#  (22, u"Gustaf's Kn\xe4ckebr\xf6d", 9, 5, u'24 - 500 g pkgs.', 21.0, 104, 0, 25, 0),
#  (23, u'Tunnbr\xf6d', 9, 5, u'12 - 250 g pkgs.', 9.0, 61, 0, 25, 0),
#  (24, u'Guaran\xe1 Fant\xe1stica', 10, 1, u'12 - 355 ml cans', 4.5, 20, 0, 0, 1),
#  (25, u'NuNuCa Nu\xdf-Nougat-Creme', 11, 3, u'20 - 450 g glasses', 14.0, 76, 0, 30, 0),
#  (26, u'Gumb\xe4r Gummib\xe4rchen', 11, 3, u'100 - 250 g bags', 31.23, 15, 0, 0, 0),
#  (27, u'Schoggi Schokolade', 11, 3, u'100 - 100 g pieces', 43.9, 49, 0, 30, 0),
#  (28, u'R\xf6ssle Sauerkraut', 12, 7, u'25 - 825 g cans', 45.6, 26, 0, 0, 1),
#  (29, u'Th\xfcringer Rostbratwurst', 12, 6, u'50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1),
#  (30, u'Nord-Ost Matjeshering', 13, 8, u'10 - 200 g glasses', 25.89, 10, 0, 15, 0),
#  (31, u'Gorgonzola Telino', 14, 4, u'12 - 100 g pkgs', 12.5, 0, 70, 20, 0),
#  (32, u'Mascarpone Fabioli', 14, 4, u'24 - 200 g pkgs.', 32.0, 9, 40, 25, 0),
#  (33, u'Geitost', 15, 4, u'500 g', 2.5, 112, 0, 20, 0),
#  (34, u'Sasquatch Ale', 16, 1, u'24 - 12 oz bottles', 14.0, 111, 0, 15, 0),
#  (35, u'Steeleye Stout', 16, 1, u'24 - 12 oz bottles', 18.0, 20, 0, 15, 0),
#  (36, u'Inlagd Sill', 17, 8, u'24 - 250 g  jars', 19.0, 112, 0, 20, 0),
#  (37, u'Gravad lax', 17, 8, u'12 - 500 g pkgs.', 26.0, 11, 50, 25, 0),
#  (38, u'C\xf4te de Blaye', 18, 1, u'12 - 75 cl bottles', 263.5, 17, 0, 15, 0),
#  (39, u'Chartreuse verte', 18, 1, u'750 cc per bottle', 18.0, 69, 0, 5, 0),
#  (40, u'Boston Crab Meat', 19, 8, u'24 - 4 oz tins', 18.4, 123, 0, 30, 0),
#  (41, u"Jack's New England Clam Chowder", 19, 8, u'12 - 12 oz cans', 9.65, 85, 0, 10, 0),
#  (42, u'Singaporean Hokkien Fried Mee', 20, 5, u'32 - 1 kg pkgs.', 14.0, 26, 0, 0, 1),
#  (43, u'Ipoh Coffee', 20, 1, u'16 - 500 g tins', 46.0, 17, 10, 25, 0),
#  (44, u'Gula Malacca', 20, 2, u'20 - 2 kg bags', 19.45, 27, 0, 15, 0),
#  (45, u'Rogede sild', 21, 8, u'1k pkg.', 9.5, 5, 70, 15, 0),
#  (46, u'Spegesild', 21, 8, u'4 - 450 g glasses', 12.0, 95, 0, 0, 0),
#  (47, u'Zaanse koeken', 22, 3, u'10 - 4 oz boxes', 9.5, 36, 0, 0, 0),
#  (48, u'Chocolade', 22, 3, u'10 pkgs.', 12.75, 15, 70, 25, 0),
#  (49, u'Maxilaku', 23, 3, u'24 - 50 g pkgs.', 20.0, 10, 60, 15, 0),
#  (50, u'Valkoinen suklaa', 23, 3, u'12 - 100 g bars', 16.25, 65, 0, 30, 0),
#  (51, u'Manjimup Dried Apples', 24, 7, u'50 - 300 g pkgs.', 53.0, 20, 0, 10, 0),
#  (52, u'Filo Mix', 24, 5, u'16 - 2 kg boxes', 7.0, 38, 0, 25, 0),
#  (53, u'Perth Pasties', 24, 6, u'48 pieces', 32.8, 0, 0, 0, 1),
#  (54, u'Tourti\xe8re', 25, 6, u'16 pies', 7.45, 21, 0, 10, 0),
#  (55, u'P\xe2t\xe9 chinois', 25, 6, u'24 boxes x 2 pies', 24.0, 115, 0, 20, 0),
#  (56, u'Gnocchi di nonna Alice', 26, 5, u'24 - 250 g pkgs.', 38.0, 21, 10, 30, 0),
#  (57, u'Ravioli Angelo', 26, 5, u'24 - 250 g pkgs.', 19.5, 36, 0, 20, 0),
#  (58, u'Escargots de Bourgogne', 27, 8, u'24 pieces', 13.25, 62, 0, 20, 0),
#  (59, u'Raclette Courdavault', 28, 4, u'5 kg pkg.', 55.0, 79, 0, 0, 0),
#  (60, u'Camembert Pierrot', 28, 4, u'15 - 300 g rounds', 34.0, 19, 0, 0, 0),
#  (61, u"Sirop d'\xe9rable", 29, 2, u'24 - 500 ml bottles', 28.5, 113, 0, 25, 0),
#  (62, u'Tarte au sucre', 29, 3, u'48 pies', 49.3, 17, 0, 0, 0),
#  (63, u'Vegie-spread', 7, 2, u'15 - 625 g jars', 43.9, 24, 0, 5, 0),
#  (64, u'Wimmers gute Semmelkn\xf6del', 12, 5, u'20 bags x 4 pieces', 33.25, 22, 80, 30, 0),
#  (65, u'Louisiana Fiery Hot Pepper Sauce', 2, 2, u'32 - 8 oz bottles', 21.05, 76, 0, 0, 0),
#  (66, u'Louisiana Hot Spiced Okra', 2, 2, u'24 - 8 oz jars', 17.0, 4, 100, 20, 0),
#  (67, u'Laughing Lumberjack Lager', 16, 1, u'24 - 12 oz bottles', 14.0, 52, 0, 10, 0),
#  (68, u'Scottish Longbreads', 8, 3, u'10 boxes x 8 pieces', 12.5, 6, 10, 15, 0),
#  (69, u'Gudbrandsdalsost', 15, 4, u'10 kg pkg.', 36.0, 26, 0, 15, 0),
#  (70, u'Outback Lager', 7, 1, u'24 - 355 ml bottles', 15.0, 15, 10, 30, 0),
#  (71, u'Flotemysost', 15, 4, u'10 - 500 g pkgs.', 21.5, 26, 0, 0, 0),
#  (72, u'Mozzarella di Giovanni', 14, 4, u'24 - 200 g pkgs.', 34.8, 14, 0, 0, 0),
#  (73, u'R\xf6d Kaviar', 17, 8, u'24 - 150 g jars', 15.0, 101, 0, 5, 0),
#  (74, u'Longlife Tofu', 4, 7, u'5 kg pkg.', 10.0, 4, 20, 5, 0),
#  (75, u'Rh\xf6nbr\xe4u Klosterbier', 12, 1, u'24 - 0.5 l bottles', 7.75, 125, 0, 25, 0),
#  (76, u'Lakkalik\xf6\xf6ri', 23, 1, u'500 ml', 18.0, 57, 0, 20, 0),
#  (77, u'Original Frankfurter gr\xfcne So\xdfe', 12, 2, u'12 boxes', 13.0, 32, 0, 15, 0)]

# %%
# %%sql
#
# SELECT "CategoryName",count("CategoryID") FROM categoriesmerged GROUP BY "CategoryName";
# Out:
# 8 rows affected.
# [(u'Beverages', 12L),
#  (u'Seafood', 12L),
#  (u'Grains/Cereals', 7L),
#  (u'Confections', 13L),
#  (u'Meat/Poultry', 6L),
#  (u'Condiments', 12L),
#  (u'Dairy Products', 10L),
#  (u'Produce', 5L)]

# %% [markdown]
# > Answer:
# ```sql
# SELECT "CategoryName", count("ProductID")
# FROM products AS p
# JOIN categories AS c
# ON p."CategoryID" = c."CategoryID"
# GROUP BY c."CategoryName"
# ```

# %% [markdown]
# - What 5 customers are generating the highest revenue? Print a table with `CustomerID` and `Total Revenue`.

# %% [markdown]
# Answer:
# ```sql
# SELECT "CustomerID",
#        CAST(
#        SUM("UnitPrice" *
#            "Quantity" *
#            (1.0 - "Discount"))
#       AS numeric(36,2))
#       AS "Revenue"
# FROM orders AS o
# JOIN order_details AS od
# ON o."OrderID" = od."OrderID"
# GROUP BY "CustomerID"
# ORDER BY "Revenue" DESC
# LIMIT 5
# ```
#
# > Check: can you infer what CAST(...) and numeric(P,s) do?

# %% [markdown]
# - In which country are the top 5 suppliers by number of units supplied? Print a table with the supplier's `CompanyName`, `Country` and total number of units supplied. (This uses four tables!)

# %% [markdown]
# >Answer:
# ```sql
# SELECT s."CompanyName", s."Country", sum(od."Quantity") AS "UnitsSupplied"
# FROM orders o
# JOIN order_details as od
# ON o."OrderID" = od."OrderID"
# JOIN products p
# ON od."ProductID" = p."ProductID"
# JOIN suppliers s
# ON s."SupplierID" = p."SupplierID"
# GROUP BY s."SupplierID"
# ORDER BY "UnitsSupplied" DESC
# LIMIT 5
# ```
# > Check: s."CompanyName" and s."Country" are [functionally dependent](https://en.wikipedia.org/wiki/Functional_dependency#Examples) on s."SupplierID". Why does that matter here? [(Answer)](http://stackoverflow.com/questions/5986127/do-all-columns-in-a-select-list-have-to-appear-in-a-group-by-clause)

# %% [markdown]
# <a name="demo_2"></a>
# ## Demo: Sub-queries (15 mins)
#
# SQL is very versatile and it can be stretched a bit further than simple JOIN operations between two different tables.
#
# ### Subqueries
#
# A _Subquery_ or _Inner query_ or _Nested query_ is a query within another SQL query. It is used to further restrict the data to be retrieved by returning data that will be used in the main query as a condition.
#
# Subqueries can be used with the SELECT, INSERT, UPDATE, and DELETE statements along with the operators like =, <, >, >=, <=, IN, BETWEEN etc.

# %% [markdown]
# #### Syntax
#
# Here is an example of a subquery. The table resulting from the subquery is used as condition in the `WHERE` condition of the main query.
#
# ```sql
# SELECT column_name1
#     FROM table_name1
#     WHERE column_name2 [Comparison Operator]
#         (SELECT column_name3
#          FROM table_name2
#          WHERE condition);
# ```

# %% [markdown]
# For example, let's extract all the `orders` from `customers` based in France.
#
# ```sql
# SELECT "OrderID", "OrderDate" FROM orders
# WHERE "CustomerID" IN
# (SELECT "CustomerID"
#  FROM customers
#  WHERE "Country" = 'France')
# ```
#
# > **Check:** How would you get the same result with a `JOIN` operation?

# %% [markdown]
# ```sql
# SELECT "OrderID", "OrderDate" FROM orders
# JOIN customers
# ON orders."CustomerID" = customers."CustomerID"
# WHERE "Country" = 'France'
# ```

# %% [markdown]
# <a name="ind-practice"></a>
# ## Independent Practice: Other SQL Commands (25 minutes)
#
# First, working in pairs: go to http://www.w3schools.com/sql and choose a command you have not heard of. Read about it for 5 minutes, then explain it to your partner (take 2.5 minutes each).
#
# Next, get started on the `join` exercises at https://pgexercises.com/questions/joins/. Bookmark this -- it's a good resource for brushing up on the basic syntax before job interviews!

# %%
# %sql SELECT NOW() FROM products
# Out:
# 77 rows affected.
# [(datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),),
#  (datetime.datetime(2016, 10, 24, 15, 25, 27, 151738, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)),)]

# %% [markdown]
# <a name="conclusion"></a>
# ## Conclusion (5 mins)
#
# In this class we have started to discover the full power of Relational databases through JOINs and sub-queries. These allow us to mix and match data from various tables, in order to extract meaningful results.

# %% [markdown]
# ### ADDITIONAL RESOURCES
#
# - [SQL Join Documentation](http://www.w3schools.com/sql/sql_join.asp)
# - [Relational Algebra](https://en.wikipedia.org/wiki/Relational_algebra)
# - [Wikipedia on JOINS](https://en.wikipedia.org/wiki/Join_(SQL))
