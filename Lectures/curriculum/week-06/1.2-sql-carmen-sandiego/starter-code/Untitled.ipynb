# %%
import psycopg2
from pandas.io import sql
# %load_ext sql

# %%
psql -d carmen -f /Users/thomas/GA-DSI/Lectures/curriculum/week-06/1.2-sql-carmen-sandiego/starter-code/world.sql

# %%
# %sql postgresql:/Users/thomas/GA-DSI/Lectures/curriculum/week-06/1.2-sql-carmen-sandiego/starter-code/world.sql
# Out:
# Format: (postgresql|mysql)://username:password@hostname/dbname, or one of []
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-9-de29a5b387ad> in <module>()
# ----> 1 get_ipython().magic(u'sql postgresql:dsi_student:gastudents@/Users/thomas/GA-DSI/Lectures/curriculum/week-06/1.2-sql-carmen-sandiego/starter-code/world.sql')
#
# /Users/thomas/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/thomas/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
# ...
