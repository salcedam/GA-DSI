# %%
"""I used the documentation in addition to the following video for help on this webscraping/API process:
    https://www.youtube.com/watch?v=yexxcrPC7U8 """

import requests
import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import praw
import json
import time
import datetime
import re
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
from IPython.core.display import HTML

driver = webdriver.PhantomJS(executable_path='/Users/thomas/Downloads/phantomjs-2.1.1-macosx/bin/phantomjs')
driver.set_window_size(300, 200) 

# %matplotlib inline

# %% [markdown]
# ## The below section is for reddit scraping

# %%
def get_replies(comment, reply_list):
    """ recursive function that goes through the reply tree of a comment """
    reply_list.append({"id": comment.id, "comment": comment.body})
    if len(comment._replies) > 0:
        for r in comment._replies:
            get_replies(r, reply_list)
    return reply_list

# %%
subreddit_dictionary={}
title_list=[]

###
Number_of_Posts=300
Number_of_Comments=12



subreddit_list=["technology","politics","news","worldnews","inthenews","Futurology","StockMarket"]

for i in range(5,len(subreddit_list)):
    count=0
    current_time=time.time()
    print "Starting Collection from r/"+subreddit_list[i]
    subreddit_posts={}
    json_name='/Users/thomas/GA-DSI/projects/projects-capstone/Work/r_'\
                        +subreddit_list[i]+'.json'
    info_for_request='get top '+str(Number_of_Posts)+' posts w/ top '+str(Number_of_Comments)+\
                        ' comments and children comments from r/'+subreddit_list[i]+\
                        "for Capstone project at General Assembly's DSI program by User: dingdong1111"
    r = praw.Reddit(user_agent=info_for_request)
    r.login('dingdong1111', '01001759',disable_warning=True)
    posts = r.get_subreddit(subreddit_list[i]).get_top_from_year(limit=Number_of_Posts)
    for post in posts:
        count+=1
        post_comments=[]
        
        post_id=post.id
        post_title=post.title
        post_score=post.score
        post_url=post.url
        post_date=datetime.datetime.fromtimestamp(post.created)
#         post_author=post.author
        
        submission = r.get_submission(submission_id=post_id)
        submission.replace_more_comments(limit=Number_of_Comments, threshold=0)
        for comment in submission.comments:
            """ loops through all comments to submission """
            x = []  # array that holds the comment and all replies
            # get all replies and append it to our array for writing to file
            post_comments.append(get_replies(comment, x))
            
        if count%20==0:
            print "  Finished",count,"Out of",Number_of_Posts
            print "    Time Elapsed:",(time.time()-current_time)/60.,"minutes"
        subreddit_posts[post_id]=[post_title,str(post_date),post_score,post_url,post_comments]
    with open(json_name, 'w') as fp:
        json.dump(subreddit_posts, fp)
    
    print "Time Spent:",(time.time()-current_time)/60.,"minutes"
    print "Finished Collection from r/"+subreddit_list[i]
    print
# Out:
# Starting Collection from r/Futurology
#   Finished 20 Out of 300
#     Time Elapsed: 8.71059374809 minutes
#   Finished 40 Out of 300
#     Time Elapsed: 17.3826767166 minutes
#   Finished 60 Out of 300
#     Time Elapsed: 26.0483352661 minutes
#   Finished 80 Out of 300
#     Time Elapsed: 34.7198677659 minutes
#   Finished 100 Out of 300
#     Time Elapsed: 43.4012860497 minutes
#   Finished 120 Out of 300
#     Time Elapsed: 52.1055244684 minutes
#   Finished 140 Out of 300
#     Time Elapsed: 60.7756651998 minutes
#   Finished 160 Out of 300
#     Time Elapsed: 69.4521248182 minutes
#   Finished 180 Out of 300
#     Time Elapsed: 78.1329490145 minutes
#   Finished 200 Out of 300
#     Time Elapsed: 86.803851517 minutes
#   Finished 220 Out of 300
#     Time Elapsed: 95.5034796675 minutes
#   Finished 240 Out of 300
#     Time Elapsed: 104.171271618 minutes
#   Finished 260 Out of 300
#     Time Elapsed: 112.703770681 minutes
#   Finished 280 Out of 300
#     Time Elapsed: 120.543548282 minutes
#   Finished 300 Out of 300
#     Time Elapsed: 129.212287815 minutes
# Time Spent: 129.242125467 minutes
# Finished Collection from r/Futurology
#
# Starting Collection from r/StockMarket
#   Finished 20 Out of 300
#     Time Elapsed: 0.705569636822 minutes
#   Finished 40 Out of 300
#     Time Elapsed: 1.37136155367 minutes
#   Finished 60 Out of 300
#     Time Elapsed: 2.03889041742 minutes
#   Finished 80 Out of 300
#     Time Elapsed: 2.70318055153 minutes
#   Finished 100 Out of 300
#     Time Elapsed: 3.40285121997 minutes
#   Finished 120 Out of 300
#     Time Elapsed: 4.13699860175 minutes
#   Finished 140 Out of 300
#     Time Elapsed: 4.80348876715 minutes
#   Finished 160 Out of 300
#     Time Elapsed: 5.47439851761 minutes
#   Finished 180 Out of 300
#     Time Elapsed: 6.13732075294 minutes
#   Finished 200 Out of 300
#     Time Elapsed: 6.80571986834 minutes
#   Finished 220 Out of 300
#     Time Elapsed: 7.50394970179 minutes
#   Finished 240 Out of 300
#     Time Elapsed: 8.17685613632 minutes
#   Finished 260 Out of 300
#     Time Elapsed: 8.843265903 minutes
#   Finished 280 Out of 300
#     Time Elapsed: 9.5064860185 minutes
#   Finished 300 Out of 300
#     Time Elapsed: 10.1743810177 minutes
# Time Spent: 10.175907135 minutes
# Finished Collection from r/StockMarket

# %%
"""THIS IS THE CODE FROM THE AFOREMENTIONED VIDEO (SEE IMPORT CELL)"""


import praw

#key in the submission ID of the Reddit thread you want to scrape
sub_id = "xxxxxx"

def get_replies(comment, reply_list):
    """ recursive function that goes through the reply tree of a comment """
    reply_list.append({"id": comment.id, "comment": comment.body})
    if len(comment._replies) > 0:
        for r in comment._replies:
            get_replies(r, reply_list)
    return reply_list


#state your purpose for conducting the comment scrape
r = praw.Reddit('get comments from xxxxxxxx for xxxxxxx by User: xxxxxxxxx')
submission = r.get_submission(submission_id=sub_id)
""" this is a costly operation due to reddit's limits but is necessary
    to get all comments and prevent errors in script """
submission.replace_more_comments(limit=None, threshold=0)

# final array for writing to file
final = []

for comment in submission.comments:
    """ loops through all comments to submission """
    x = []  # array that holds the comment and all replies
    # get all replies and append it to our array for writing to file
    final.append(get_replies(comment, x))

with open('comments.csv', 'a') as outf:
    """ open file and write to it """
    # 2 dimension array needs two for loops
    for ele in final:
        for ele2 in ele:
            # write to file in the proper comma delimited format, one per line
            outf.write(u"{0},{1}\n".format(ele2['id'], ele2['comment']).encode('utf-8'))

# %% [markdown]
# ## The below section is for federalreserve.gov scraping
#
# https://www.federalreserve.gov/newsevents/press/all/2016all.htm

# %%
fed_dict={}

sites=["https://www.federalreserve.gov/newsevents/press/all/2016all.htm",\
       "https://www.federalreserve.gov/newsevents/press/all/2015all.htm"]
r=[]
for site in sites:
    r.append(requests.get(site))
for i in range(len(r)):
    soup=BeautifulSoup.BeautifulSoup(r[i].text)
    urls=['https://www.federalreserve.gov'+str(x.find('a')['href']) for x in soup.findAll("div",{'class':'indent'})]
    titles=[x.find('a').text for x in soup.findAll("div",{'class':'indent'})]
    dates=[str('https://www.federalreserve.gov'+str(x.find('a')['href']))[-13:-5] \
                     for x in soup.findAll("div",{'class':'indent'})]
    documents=[]
    for url in urls:
        r2=requests.get(url)
        soup=BeautifulSoup.BeautifulSoup(r2.text)
        documents.append([x.text for x in soup.findAll('p')[1:]])
    for a,b,c,d in zip(dates,titles,urls,documents):
        fed_dict[a]=[b,c,d]
with open("/Users/thomas/GA-DSI/projects/projects-capstone/Work/fed_info.json", 'w') as fp:
    json.dump(fed_dict, fp)

# %% [markdown]
# ## The following is scraping code for S&P companies off of nasdaq.com
#
# (https://github.com/datasets/s-and-p-500-companies/blob/master/data/constituents-financials.csv)
#
# (http://www.nasdaq.com/symbol/mmm/historical)
#
# (https://www.youtube.com/watch?v=Q6tLD7R-nKc)

# %%
site="https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents-financials.csv"
save_file='/Users/thomas/GA-DSI/projects/projects-capstone/Work/s&p_stock_info.csv'
pd.read_csv(site).to_csv(save_file)
tickers=pd.read_csv(save_file)['Symbol']
tickers=[x for x in tickers]

# %%
#Format is (DATE,OPEN,HIGH,LOW,CLOSE/LAST,VOLUME)
select_id='ddlTimeFrame'
select_value="1 Year"
stock_dict={}
timing_counter=1
curr_time=time.time()
for ticker in tickers:
    driver = webdriver.PhantomJS(executable_path='/Users/thomas/Downloads/phantomjs-2.1.1-macosx/bin/phantomjs')
    driver.set_window_size(300, 200) 
    url='http://www.nasdaq.com/symbol/'+ticker.lower()+'/historical'
    driver.get(url)
    time.sleep(1)
    timedropdown=WebDriverWait(driver,5).until(lambda driver: driver.find_element_by_id(select_id))
    Select(timedropdown).select_by_visible_text(select_value)
    time.sleep(1)
    soup=BeautifulSoup.BeautifulSoup(driver.page_source)
    temp=[x.text for x in soup.findAll('td')][15:-2]
    temp_l=[]
    for i in range(int(len(temp)/6.)):
        current=i*6
        temp_l.append([temp[current],temp[current+1],temp[current+2],temp[current+3],\
                       temp[current+4],temp[current+5]])
    stock_dict[ticker]=temp_l
    time.sleep(1)
    if timing_counter%25!=0:
        print "Have completed %s of 500 stocks"%timing_counter
    if timing_counter%25==0:
        print "Have completed %s of 500 stocks"%timing_counter
        print "  Elapsed Time: %s minutes"%((time.time()-curr_time)/60.)
    timing_counter+=1
    driver.close()
    
with open("/Users/thomas/GA-DSI/projects/projects-capstone/Work/s&p_stock_prices.json", 'w') as fp:
    json.dump(stock_dict, fp)
# Out:
# Have completed 1 of 500 stocks
# Have completed 2 of 500 stocks
# Have completed 3 of 500 stocks
# Have completed 4 of 500 stocks
# Have completed 5 of 500 stocks
# Have completed 6 of 500 stocks
# Have completed 7 of 500 stocks
# Have completed 8 of 500 stocks
# Have completed 9 of 500 stocks
# Have completed 10 of 500 stocks
# Have completed 11 of 500 stocks
# Have completed 12 of 500 stocks
# Have completed 13 of 500 stocks
# Have completed 14 of 500 stocks
# Have completed 15 of 500 stocks
# Have completed 16 of 500 stocks
# Have completed 17 of 500 stocks
# Have completed 18 of 500 stocks
# Have completed 19 of 500 stocks
# Have completed 20 of 500 stocks
# Have completed 21 of 500 stocks
# Have completed 22 of 500 stocks
# Have completed 23 of 500 stocks
# Have completed 24 of 500 stocks
# Have completed 25 of 500 stocks
#   Elapsed Time: 88.0071369171 minutes
# Have completed 26 of 500 stocks
# Have completed 27 of 500 stocks
# Have completed 28 of 500 stocks
# Have completed 29 of 500 stocks
# Have completed 30 of 500 stocks
# Have completed 31 of 500 stocks
# Have completed 32 of 500 stocks
# Have completed 33 of 500 stocks
# Have completed 34 of 500 stocks
# Have completed 35 of 500 stocks
# Have completed 36 of 500 stocks
# Have completed 37 of 500 stocks
# Have completed 38 of 500 stocks
# Have completed 39 of 500 stocks
# Have completed 40 of 500 stocks
# Have completed 41 of 500 stocks
# Have completed 42 of 500 stocks
# Have completed 43 of 500 stocks
# Have completed 44 of 500 stocks
# Have completed 45 of 500 stocks
# Have completed 46 of 500 stocks
# Have completed 47 of 500 stocks
# Have completed 48 of 500 stocks
# Have completed 49 of 500 stocks
# Have completed 50 of 500 stocks
# Have completed 51 of 500 stocks
# Have completed 52 of 500 stocks
# Have completed 53 of 500 stocks
# Have completed 54 of 500 stocks
# Have completed 55 of 500 stocks
# Have completed 56 of 500 stocks
# Have completed 57 of 500 stocks
# Have completed 58 of 500 stocks
# Have completed 59 of 500 stocks
# Have completed 60 of 500 stocks
# Have completed 61 of 500 stocks
# Have completed 62 of 500 stocks
# Have completed 63 of 500 stocks
# Have completed 64 of 500 stocks
# Have completed 65 of 500 stocks
# Have completed 66 of 500 stocks
# Have completed 67 of 500 stocks
# Have completed 68 of 500 stocks
# Have completed 69 of 500 stocks
# Have completed 70 of 500 stocks
# Have completed 71 of 500 stocks
# Have completed 72 of 500 stocks
# Have completed 73 of 500 stocks
# Have completed 74 of 500 stocks
# Have completed 75 of 500 stocks
# Have completed 76 of 500 stocks
# Have completed 77 of 500 stocks
# Have completed 78 of 500 stocks
# Have completed 79 of 500 stocks
# Have completed 80 of 500 stocks
# Have completed 81 of 500 stocks
# Have completed 82 of 500 stocks
# Have completed 83 of 500 stocks
# Have completed 84 of 500 stocks
# Have completed 85 of 500 stocks
# Have completed 86 of 500 stocks
# Have completed 87 of 500 stocks
# Have completed 88 of 500 stocks
# Have completed 89 of 500 stocks
# Have completed 90 of 500 stocks
# Have completed 91 of 500 stocks
# Have completed 92 of 500 stocks
# Have completed 93 of 500 stocks
# Have completed 94 of 500 stocks
# Have completed 95 of 500 stocks
# Have completed 96 of 500 stocks
# Have completed 97 of 500 stocks
# Have completed 98 of 500 stocks
# Have completed 99 of 500 stocks
# Have completed 100 of 500 stocks
# Have completed 101 of 500 stocks
# Have completed 102 of 500 stocks
# Have completed 103 of 500 stocks
# Have completed 104 of 500 stocks
# Have completed 105 of 500 stocks
# Have completed 106 of 500 stocks
# Have completed 107 of 500 stocks
# Have completed 108 of 500 stocks
# Have completed 109 of 500 stocks
# Have completed 110 of 500 stocks
# Have completed 111 of 500 stocks
# Have completed 112 of 500 stocks
# Have completed 113 of 500 stocks
# Have completed 114 of 500 stocks
# Have completed 115 of 500 stocks
# Have completed 116 of 500 stocks
# Have completed 117 of 500 stocks
# Have completed 118 of 500 stocks
# Have completed 119 of 500 stocks
# Have completed 120 of 500 stocks
# Have completed 121 of 500 stocks
# Have completed 122 of 500 stocks
# Have completed 123 of 500 stocks
# Have completed 124 of 500 stocks
# Have completed 125 of 500 stocks
# Have completed 126 of 500 stocks
# Have completed 127 of 500 stocks
# Have completed 128 of 500 stocks
# Have completed 129 of 500 stocks
# Have completed 130 of 500 stocks
# Have completed 131 of 500 stocks
# Have completed 132 of 500 stocks
# Have completed 133 of 500 stocks
# Have completed 134 of 500 stocks
# Have completed 135 of 500 stocks
# Have completed 136 of 500 stocks
# Have completed 137 of 500 stocks
# Have completed 138 of 500 stocks
# Have completed 139 of 500 stocks
# Have completed 140 of 500 stocks
# Have completed 141 of 500 stocks
# Have completed 142 of 500 stocks
# Have completed 143 of 500 stocks
# Have completed 144 of 500 stocks
# Have completed 145 of 500 stocks
# Have completed 146 of 500 stocks
# Have completed 147 of 500 stocks
# Have completed 148 of 500 stocks
# Have completed 149 of 500 stocks
# Have completed 150 of 500 stocks
# Have completed 151 of 500 stocks
# Have completed 152 of 500 stocks
# Have completed 153 of 500 stocks
# Have completed 154 of 500 stocks
# Have completed 155 of 500 stocks
# Have completed 156 of 500 stocks
# Have completed 157 of 500 stocks
# Have completed 158 of 500 stocks
# Have completed 159 of 500 stocks
# Have completed 160 of 500 stocks
# Have completed 161 of 500 stocks
# Have completed 162 of 500 stocks
# Have completed 163 of 500 stocks
# Have completed 164 of 500 stocks
# Have completed 165 of 500 stocks
# Have completed 166 of 500 stocks
# Have completed 167 of 500 stocks
# Have completed 168 of 500 stocks
# Have completed 169 of 500 stocks
# Have completed 170 of 500 stocks
# Have completed 171 of 500 stocks
# Have completed 172 of 500 stocks
# Have completed 173 of 500 stocks
# Have completed 174 of 500 stocks
# Have completed 175 of 500 stocks
# Have completed 176 of 500 stocks
# Have completed 177 of 500 stocks
# Have completed 178 of 500 stocks
# Have completed 179 of 500 stocks
# Have completed 180 of 500 stocks
# Have completed 181 of 500 stocks
# Have completed 182 of 500 stocks
# Have completed 183 of 500 stocks
# Have completed 184 of 500 stocks
# Have completed 185 of 500 stocks
# Have completed 186 of 500 stocks
# Have completed 187 of 500 stocks
# Have completed 188 of 500 stocks
# Have completed 189 of 500 stocks
# Have completed 190 of 500 stocks
# Have completed 191 of 500 stocks
# Have completed 192 of 500 stocks
# Have completed 193 of 500 stocks
# Have completed 194 of 500 stocks
# Have completed 195 of 500 stocks
# Have completed 196 of 500 stocks
# Have completed 197 of 500 stocks
# Have completed 198 of 500 stocks
# Have completed 199 of 500 stocks
# Have completed 200 of 500 stocks
# Have completed 201 of 500 stocks
# Have completed 202 of 500 stocks
# Have completed 203 of 500 stocks
# Have completed 204 of 500 stocks
# Have completed 205 of 500 stocks
# Have completed 206 of 500 stocks
# Have completed 207 of 500 stocks
# Have completed 208 of 500 stocks
# Have completed 209 of 500 stocks
# Have completed 210 of 500 stocks
# Have completed 211 of 500 stocks
# Have completed 212 of 500 stocks
# Have completed 213 of 500 stocks
# Have completed 214 of 500 stocks
# Have completed 215 of 500 stocks
# Have completed 216 of 500 stocks
# Have completed 217 of 500 stocks
# Have completed 218 of 500 stocks
# Have completed 219 of 500 stocks
# Have completed 220 of 500 stocks
# Have completed 221 of 500 stocks
# Have completed 222 of 500 stocks
# Have completed 223 of 500 stocks
# Have completed 224 of 500 stocks
# Have completed 225 of 500 stocks
# Have completed 226 of 500 stocks
# Have completed 227 of 500 stocks
# Have completed 228 of 500 stocks
# Have completed 229 of 500 stocks
# Have completed 230 of 500 stocks
# Have completed 231 of 500 stocks
# Have completed 232 of 500 stocks
# Have completed 233 of 500 stocks
# Have completed 234 of 500 stocks
# Have completed 235 of 500 stocks
# Have completed 236 of 500 stocks
# Have completed 237 of 500 stocks
# Have completed 238 of 500 stocks
# Have completed 239 of 500 stocks
# Have completed 240 of 500 stocks
# Have completed 241 of 500 stocks
# Have completed 242 of 500 stocks
# Have completed 243 of 500 stocks
# Have completed 244 of 500 stocks
# Have completed 245 of 500 stocks
# Have completed 246 of 500 stocks
# Have completed 247 of 500 stocks
# Have completed 248 of 500 stocks
# Have completed 249 of 500 stocks
# Have completed 250 of 500 stocks
# Have completed 251 of 500 stocks
# Have completed 252 of 500 stocks
# Have completed 253 of 500 stocks
# Have completed 254 of 500 stocks
# Have completed 255 of 500 stocks
# Have completed 256 of 500 stocks
# Have completed 257 of 500 stocks
# Have completed 258 of 500 stocks
# Have completed 259 of 500 stocks
# Have completed 260 of 500 stocks
# Have completed 261 of 500 stocks
# Have completed 262 of 500 stocks
# Have completed 263 of 500 stocks
# Have completed 264 of 500 stocks
# Have completed 265 of 500 stocks
# Have completed 266 of 500 stocks
# Have completed 267 of 500 stocks
# Have completed 268 of 500 stocks
# Have completed 269 of 500 stocks
# Have completed 270 of 500 stocks
# Have completed 271 of 500 stocks
# Have completed 272 of 500 stocks
# Have completed 273 of 500 stocks
# Have completed 274 of 500 stocks
# Have completed 275 of 500 stocks
# Have completed 276 of 500 stocks
# Have completed 277 of 500 stocks
# Have completed 278 of 500 stocks
# Have completed 279 of 500 stocks
# Have completed 280 of 500 stocks
# Have completed 281 of 500 stocks
# Have completed 282 of 500 stocks
# Have completed 283 of 500 stocks
# Have completed 284 of 500 stocks
# Have completed 285 of 500 stocks
# Have completed 286 of 500 stocks
# Have completed 287 of 500 stocks
# Have completed 288 of 500 stocks
# Have completed 289 of 500 stocks
# Have completed 290 of 500 stocks
# Have completed 291 of 500 stocks
# Have completed 292 of 500 stocks
# Have completed 293 of 500 stocks
# Have completed 294 of 500 stocks
# Have completed 295 of 500 stocks
# Have completed 296 of 500 stocks
# Have completed 297 of 500 stocks
# Have completed 298 of 500 stocks
# Have completed 299 of 500 stocks
# Have completed 300 of 500 stocks
# Have completed 301 of 500 stocks
# Have completed 302 of 500 stocks
# Have completed 303 of 500 stocks
# Have completed 304 of 500 stocks
# Have completed 305 of 500 stocks
# Have completed 306 of 500 stocks
# Have completed 307 of 500 stocks
# Have completed 308 of 500 stocks
# Have completed 309 of 500 stocks
# Have completed 310 of 500 stocks
# Have completed 311 of 500 stocks
# Have completed 312 of 500 stocks
# Have completed 313 of 500 stocks
# Have completed 314 of 500 stocks
# Have completed 315 of 500 stocks
# Have completed 316 of 500 stocks
# Have completed 317 of 500 stocks
# Have completed 318 of 500 stocks
# Have completed 319 of 500 stocks
# Have completed 320 of 500 stocks
# Have completed 321 of 500 stocks
# Have completed 322 of 500 stocks
# Have completed 323 of 500 stocks
# Have completed 324 of 500 stocks
# Have completed 325 of 500 stocks
# Have completed 326 of 500 stocks
# Have completed 327 of 500 stocks
# Have completed 328 of 500 stocks
# Have completed 329 of 500 stocks
# Have completed 330 of 500 stocks
# Have completed 331 of 500 stocks
# Have completed 332 of 500 stocks
# Have completed 333 of 500 stocks
# Have completed 334 of 500 stocks
# Have completed 335 of 500 stocks
# Have completed 336 of 500 stocks
# Have completed 337 of 500 stocks
# Have completed 338 of 500 stocks
# Have completed 339 of 500 stocks
# Have completed 340 of 500 stocks
# Have completed 341 of 500 stocks
# Have completed 342 of 500 stocks
# Have completed 343 of 500 stocks
# Have completed 344 of 500 stocks
# Have completed 345 of 500 stocks
# Have completed 346 of 500 stocks
# Have completed 347 of 500 stocks
# Have completed 348 of 500 stocks
# Have completed 349 of 500 stocks
# Have completed 350 of 500 stocks
# Have completed 351 of 500 stocks
# Have completed 352 of 500 stocks
# Have completed 353 of 500 stocks
# Have completed 354 of 500 stocks
# Have completed 355 of 500 stocks
# Have completed 356 of 500 stocks
# Have completed 357 of 500 stocks
# Have completed 358 of 500 stocks
# Have completed 359 of 500 stocks
# Have completed 360 of 500 stocks
# Have completed 361 of 500 stocks
# Have completed 362 of 500 stocks
# Have completed 363 of 500 stocks
# Have completed 364 of 500 stocks
# Have completed 365 of 500 stocks
# Have completed 366 of 500 stocks
# Have completed 367 of 500 stocks
# Have completed 368 of 500 stocks
# Have completed 369 of 500 stocks
# Have completed 370 of 500 stocks
# Have completed 371 of 500 stocks
# Have completed 372 of 500 stocks
# Have completed 373 of 500 stocks
# Have completed 374 of 500 stocks
# Have completed 375 of 500 stocks
# Have completed 376 of 500 stocks
# Have completed 377 of 500 stocks
# Have completed 378 of 500 stocks
# Have completed 379 of 500 stocks
# Have completed 380 of 500 stocks
# Have completed 381 of 500 stocks
# Have completed 382 of 500 stocks
# Have completed 383 of 500 stocks
# Have completed 384 of 500 stocks
# Have completed 385 of 500 stocks
# Have completed 386 of 500 stocks
# Have completed 387 of 500 stocks
# Have completed 388 of 500 stocks
# Have completed 389 of 500 stocks
# Have completed 390 of 500 stocks
# Have completed 391 of 500 stocks
# Have completed 392 of 500 stocks
# Have completed 393 of 500 stocks
# Have completed 394 of 500 stocks
# Have completed 395 of 500 stocks
# Have completed 396 of 500 stocks
# Have completed 397 of 500 stocks
# Have completed 398 of 500 stocks
# Have completed 399 of 500 stocks
# Have completed 400 of 500 stocks
# Have completed 401 of 500 stocks
# Have completed 402 of 500 stocks
# Have completed 403 of 500 stocks
# Have completed 404 of 500 stocks
# Have completed 405 of 500 stocks
# Have completed 406 of 500 stocks
# Have completed 407 of 500 stocks
# Have completed 408 of 500 stocks
# Have completed 409 of 500 stocks
# Have completed 410 of 500 stocks
# Have completed 411 of 500 stocks
# Have completed 412 of 500 stocks
# Have completed 413 of 500 stocks
# Have completed 414 of 500 stocks
# Have completed 415 of 500 stocks
# Have completed 416 of 500 stocks
# Have completed 417 of 500 stocks
# Have completed 418 of 500 stocks
# Have completed 419 of 500 stocks
# Have completed 420 of 500 stocks
# Have completed 421 of 500 stocks
# Have completed 422 of 500 stocks
# Have completed 423 of 500 stocks
# Have completed 424 of 500 stocks
# Have completed 425 of 500 stocks
# Have completed 426 of 500 stocks
# Have completed 427 of 500 stocks
# Have completed 428 of 500 stocks
# Have completed 429 of 500 stocks
# Have completed 430 of 500 stocks
# Have completed 431 of 500 stocks
# Have completed 432 of 500 stocks
# Have completed 433 of 500 stocks
# Have completed 434 of 500 stocks
# Have completed 435 of 500 stocks
# Have completed 436 of 500 stocks
# Have completed 437 of 500 stocks
# Have completed 438 of 500 stocks
# Have completed 439 of 500 stocks
# Have completed 440 of 500 stocks
# Have completed 441 of 500 stocks
# Have completed 442 of 500 stocks
# Have completed 443 of 500 stocks
# Have completed 444 of 500 stocks
# Have completed 445 of 500 stocks
# Have completed 446 of 500 stocks
# Have completed 447 of 500 stocks
# Have completed 448 of 500 stocks
# Have completed 449 of 500 stocks
# Have completed 450 of 500 stocks
# Have completed 451 of 500 stocks
# Have completed 452 of 500 stocks
# Have completed 453 of 500 stocks
# Have completed 454 of 500 stocks
# Have completed 455 of 500 stocks
# Have completed 456 of 500 stocks
# Have completed 457 of 500 stocks
# Have completed 458 of 500 stocks
# Have completed 459 of 500 stocks
# Have completed 460 of 500 stocks
# Have completed 461 of 500 stocks
# Have completed 462 of 500 stocks
# Have completed 463 of 500 stocks
# Have completed 464 of 500 stocks
# Have completed 465 of 500 stocks
# Have completed 466 of 500 stocks
# Have completed 467 of 500 stocks
# Have completed 468 of 500 stocks
# Have completed 469 of 500 stocks
# Have completed 470 of 500 stocks
# Have completed 471 of 500 stocks
# Have completed 472 of 500 stocks
# Have completed 473 of 500 stocks
# Have completed 474 of 500 stocks
# Have completed 475 of 500 stocks
# Have completed 476 of 500 stocks
# Have completed 477 of 500 stocks
# Have completed 478 of 500 stocks
# Have completed 479 of 500 stocks
# Have completed 480 of 500 stocks
# Have completed 481 of 500 stocks
# Have completed 482 of 500 stocks
# Have completed 483 of 500 stocks
# Have completed 484 of 500 stocks
# Have completed 485 of 500 stocks
# Have completed 486 of 500 stocks
# Have completed 487 of 500 stocks
# Have completed 488 of 500 stocks
# Have completed 489 of 500 stocks
# Have completed 490 of 500 stocks
# Have completed 491 of 500 stocks
# Have completed 492 of 500 stocks
# Have completed 493 of 500 stocks
# Have completed 494 of 500 stocks
# Have completed 495 of 500 stocks
# Have completed 496 of 500 stocks
# Have completed 497 of 500 stocks
# Have completed 498 of 500 stocks
# Have completed 499 of 500 stocks
# Have completed 500 of 500 stocks
# Have completed 501 of 500 stocks
# Have completed 502 of 500 stocks
# Have completed 503 of 500 stocks
# Have completed 504 of 500 stocks

# %%
r=requests.get('http://www.nasdaq.com/symbol/ford/financials?query=income-statement')
