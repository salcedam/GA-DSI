# %%
x=3
print x
# Out:
# 3

# %% [markdown]
# This is a Markdown mode cell.
#
# You won't see it as a cell as a viewer, but you can alter it by selecting it.

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'bo')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
s=np.arange(0,3.1,.01)
plt.plot(s,'r',s**2,'b',linewidth=1) #Linewidth is an optional argument
plt.axis([-15,330,-.5,10])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
s=np.arange(0,3.1,.01)
