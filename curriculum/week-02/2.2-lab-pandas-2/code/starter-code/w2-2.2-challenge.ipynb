# %%
import pandas as pd
import numpy as np
f=pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/star-wars-survey/StarWars.csv")
df=pd.DataFrame(f)
df.iloc[:2,:].T
new_cols=["ID","Seen Any","Fan","Seen Ep.1","Seen Ep.2","Seen Ep.3","Seen Ep.4","Seen Ep.5","Seen Ep.6",\
         "Ep.1 Pref","Ep.2 Pref","Ep.3 Pref","Ep.4 Pref","Ep.5 Pref","Ep.6 Pref","Han Solo","Luke Skywalker",\
         "Princess Leia Organa","Anakin Skywalker","Obi Wan Kenobi","Emperor Palpatine","Darth Vader",\
          "Lando Calrissian","Boba Fett","C-3P0","R2 D2","Jar Jar Binks","Padme Amidala",\
          "Yoda","Who Shot First","Familiar w/ Expanded Uni","Fan of Expanded Uni","Fan of Star Trek",\
          "Gender","Age","Household Income","Education","Location"]
df.columns=new_cols
df=df.iloc[1:,:]
df
# Out:
#                 ID Seen Any  Fan                                 Seen Ep.1  \
# 1     3.292880e+09      Yes  Yes  Star Wars: Episode I  The Phantom Menace
# 2     3.292880e+09       No  NaN                                       NaN
# 3     3.292765e+09      Yes   No  Star Wars: Episode I  The Phantom Menace
# 4     3.292763e+09      Yes  Yes  Star Wars: Episode I  The Phantom Menace
# 5     3.292731e+09      Yes  Yes  Star Wars: Episode I  The Phantom Menace
# 6     3.292719e+09      Yes  Yes  Star Wars: Episode I  The Phantom Menace
# 7     3.292685e+09      Yes  Yes  Star Wars: Episode I  The Phantom Menace
# 8     3.292664e+09      Yes  Yes  Star Wars: Episode I  The Phantom Menace
# 9     3.292654e+09      Yes  Yes  Star Wars: Episode I  The Phantom Menace
# 10    3.292640e+09      Yes   No                                       NaN
# 11    3.292638e+09      Yes  NaN                                       NaN
# ...

# %% [markdown]
# Let's use the Star Wars dataset again. Load it in and pull up the head.
#
# ```../../../1.2-study-design/assets/datasets/StarWars.csv```

# %% [markdown]
# #### Create a hypothesis involving different subsections of the data.
#
# For example:
# - Are respondents more likely to respond "Han" to the question "Who shot first?" if they also say they are fans of Star Trek?
#
# Type your hypothesis in a markdown cell below:

# %% [markdown]
# Use boolean indexing to create subsets of the data to support your hypothesis. See if you can answer questions using mutiple variables.

# %%
yfan=df[(df["Fan of Star Trek"]=="Yes")&(df["Who Shot First"]=="Han")]
nfan=df[(df["Fan of Star Trek"]=="No")&(df["Who Shot First"]=="Han")]
if len(yfan)>len(nfan):
    print "Yes"
else:
    print "No"
# Out:
# Yes

# %% [markdown]
# **Bonus** : Use matplotlib or seaborn to present your findings.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
lyfan=len(yfan["Fan of Star Trek"])
lnfan=len(nfan["Fan of Star Trek"])
c2=[lyfan,lnfan]

plt.bar([.6],lyfan,label="Yes",color=(.3,1,.3,1))
plt.bar([1.6],lnfan,label="No",color=(1,0,0,1))
plt.legend(loc="upper right")
plt.xticks([])
plt.title("Are people who said 'Han Solo' Star Trek Fans?")
plt.ylabel("Votes")
plt.ylim(0,225)
plt.show()

# %% [markdown]
# **Bonus 2** : Create another, more complex hypothesis, support it, and plot it below.

# %%
#comb.hist("Fan of Star Trek")
yes=[]
no=[]
for x in comb["Fan of Star Trek"]:
    if x=="Yes":
        yes.append("Yes")
    else:
        no.append("No")
c2=yes+no
